# %%
#import dependencies and API key
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

#set url variable
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000,high=90.000, size=9000)
longs = np.random.uniform(low=-180.000,high=180.000, size =9000)
lats_longs = zip(lats,longs)
lats_longs

# %%
#add the lats and longs to a list
coordinates = list(lats_longs)

#create an empty list for holding the cities
cities = []

# Get the nearest city using the citipy module.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #if the city is unique then we will add it to the cities list
    if city not in cities:
        cities.append(city)

#print the city count to confirm sufficient count of at least 2000
len(cities)
# Out:
# 2099

# %%
#create an empty list to hold the weather data
city_data = []

#print the beginning of the logging
print('Beginning Data Retrieval    ')
print('----------------------------')

#create counters
record_count = 1
set_count = 1

#loop through all the cities in our list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    #create endpoint url with each city
    city_url = url + '&q=' + city.replace(' ','+')
    
    #log the URl, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    
    #add 1 to the record count
    record_count += 1

# Perform an API call with the OpenWeatherMap.
    try:
        #parse the JSON data and retrieve data
        city_weather = requests.get(city_url).json()
        
        #parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_long = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        #append the city information into city_data list
        city_data.append({
            'City':city.title(),
            'Country':city_country,
            'Lat':city_lat,
            'Lng':city_long,
            'Max Temp':city_max_temp,
            'Humidity':city_humidity,
            'Cloudiness':city_clouds,
            'Wind Speed':city_wind,
            'Current Description':city_description})

#if an error is experienced, skip the city 
    except:
        print('City is not found. Skipping...')
        pass
    
#indicate that Data Loading is Complete
print('----------------------------')
print('Data Retrieval is Complete  ')
print('----------------------------')
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | kaitangata
# Processing Record 2 of Set 1 | lazaro cardenas
# Processing Record 3 of Set 1 | oktyabrskoye
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | narsaq
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | saskylakh
# Processing Record 8 of Set 1 | hovd
# Processing Record 9 of Set 1 | igarka
# Processing Record 10 of Set 1 | ilulissat
# Processing Record 11 of Set 1 | san ignacio
# Processing Record 12 of Set 1 | provideniya
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 | pangnirtung
# Processing Record 15 of Set 1 | turukhansk
# Processing Record 16 of Set 1 | nizhneyansk
# City is not found. Skipping...
# Processing Record 17 of Set 1 | mangrol
# Processing Record 18 of Set 1 | camacha
# Processing Record 19 of Set 1 | toliary
# City is not found. Skipping...
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | saint anthony
# Processing Record 22 of Set 1 | uetze
# Processing Record 23 of Set 1 | santa lucia
# Processing Record 24 of Set 1 | norman wells
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | elko
# Processing Record 27 of Set 1 | victoria
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | carnarvon
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | esperance
# Processing Record 32 of Set 1 | yanan
# City is not found. Skipping...
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | ksenyevka
# City is not found. Skipping...
# Processing Record 35 of Set 1 | leningradskiy
# Processing Record 36 of Set 1 | chicama
# Processing Record 37 of Set 1 | ixtapa
# Processing Record 38 of Set 1 | taolanaro
# City is not found. Skipping...
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | hvolsvollur
# Processing Record 42 of Set 1 | avarua
# Processing Record 43 of Set 1 | geraldton
# Processing Record 44 of Set 1 | port lincoln
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | buraydah
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | attawapiskat
# City is not found. Skipping...
# Processing Record 2 of Set 2 | chokurdakh
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | samusu
# City is not found. Skipping...
# Processing Record 5 of Set 2 | tuktoyaktuk
# Processing Record 6 of Set 2 | mahaicony
# City is not found. Skipping...
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | puerto ayora
# Processing Record 9 of Set 2 | los llanos de aridane
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | lagos
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | albany
# Processing Record 14 of Set 2 | stepnogorsk
# Processing Record 15 of Set 2 | manokwari
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | songjianghe
# Processing Record 18 of Set 2 | vaini
# Processing Record 19 of Set 2 | floresta
# Processing Record 20 of Set 2 | dolbeau
# City is not found. Skipping...
# Processing Record 21 of Set 2 | le port
# Processing Record 22 of Set 2 | palang
# Processing Record 23 of Set 2 | bambous virieux
# Processing Record 24 of Set 2 | barrow
# Processing Record 25 of Set 2 | hualmay
# Processing Record 26 of Set 2 | tsihombe
# City is not found. Skipping...
# Processing Record 27 of Set 2 | zalantun
# Processing Record 28 of Set 2 | sorland
# Processing Record 29 of Set 2 | samarkand
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | half moon bay
# Processing Record 33 of Set 2 | kununurra
# Processing Record 34 of Set 2 | mazamari
# Processing Record 35 of Set 2 | barentsburg
# City is not found. Skipping...
# Processing Record 36 of Set 2 | palmer
# Processing Record 37 of Set 2 | norsup
# Processing Record 38 of Set 2 | aksarka
# Processing Record 39 of Set 2 | pacific grove
# Processing Record 40 of Set 2 | karakol
# Processing Record 41 of Set 2 | gat
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | saint george
# Processing Record 45 of Set 2 | beloha
# Processing Record 46 of Set 2 | new norfolk
# Processing Record 47 of Set 2 | porto santo
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | karatau
# Processing Record 50 of Set 2 | resistencia
# Processing Record 1 of Set 3 | cidreira
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | kyzyl-suu
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | mattru
# Processing Record 6 of Set 3 | busselton
# Processing Record 7 of Set 3 | illoqqortoormiut
# City is not found. Skipping...
# Processing Record 8 of Set 3 | tubruq
# City is not found. Skipping...
# Processing Record 9 of Set 3 | xiaoshi
# Processing Record 10 of Set 3 | hofn
# Processing Record 11 of Set 3 | mogadishu
# Processing Record 12 of Set 3 | pundaguitan
# Processing Record 13 of Set 3 | port elizabeth
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | gornopravdinsk
# Processing Record 16 of Set 3 | santiago del estero
# Processing Record 17 of Set 3 | palu
# Processing Record 18 of Set 3 | monrovia
# Processing Record 19 of Set 3 | bariri
# Processing Record 20 of Set 3 | khatanga
# Processing Record 21 of Set 3 | pevek
# Processing Record 22 of Set 3 | chute-aux-outardes
# Processing Record 23 of Set 3 | porto belo
# Processing Record 24 of Set 3 | mount isa
# Processing Record 25 of Set 3 | aflu
# City is not found. Skipping...
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | seminole
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | ust-tsilma
# Processing Record 30 of Set 3 | coruripe
# Processing Record 31 of Set 3 | punta arenas
# Processing Record 32 of Set 3 | vila velha
# Processing Record 33 of Set 3 | cienaga
# Processing Record 34 of Set 3 | gbadolite
# Processing Record 35 of Set 3 | severo-kurilsk
# Processing Record 36 of Set 3 | merauke
# Processing Record 37 of Set 3 | zinder
# Processing Record 38 of Set 3 | mandalgovi
# Processing Record 39 of Set 3 | tuatapere
# Processing Record 40 of Set 3 | bengkulu
# Processing Record 41 of Set 3 | nalut
# Processing Record 42 of Set 3 | vaitupu
# City is not found. Skipping...
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | thompson
# Processing Record 46 of Set 3 | coquimbo
# Processing Record 47 of Set 3 | pisco
# Processing Record 48 of Set 3 | porto novo
# Processing Record 49 of Set 3 | batsfjord
# Processing Record 50 of Set 3 | hambantota
# Processing Record 1 of Set 4 | saint-philippe
# Processing Record 2 of Set 4 | winnemucca
# Processing Record 3 of Set 4 | samarai
# Processing Record 4 of Set 4 | wenling
# Processing Record 5 of Set 4 | flinders
# Processing Record 6 of Set 4 | angoram
# Processing Record 7 of Set 4 | hearst
# Processing Record 8 of Set 4 | careiro da varzea
# Processing Record 9 of Set 4 | dauriya
# Processing Record 10 of Set 4 | yar-sale
# Processing Record 11 of Set 4 | adrar
# Processing Record 12 of Set 4 | flers
# Processing Record 13 of Set 4 | kuche
# City is not found. Skipping...
# Processing Record 14 of Set 4 | vestmanna
# Processing Record 15 of Set 4 | saint-leu
# Processing Record 16 of Set 4 | pampa
# Processing Record 17 of Set 4 | orlik
# Processing Record 18 of Set 4 | bilibino
# Processing Record 19 of Set 4 | odweyne
# Processing Record 20 of Set 4 | beidao
# Processing Record 21 of Set 4 | usinsk
# Processing Record 22 of Set 4 | acarau
# Processing Record 23 of Set 4 | kirakira
# Processing Record 24 of Set 4 | bluff
# Processing Record 25 of Set 4 | port blair
# Processing Record 26 of Set 4 | kiruna
# Processing Record 27 of Set 4 | lasa
# Processing Record 28 of Set 4 | tigil
# Processing Record 29 of Set 4 | atasu
# Processing Record 30 of Set 4 | isangel
# Processing Record 31 of Set 4 | kruisfontein
# Processing Record 32 of Set 4 | paucartambo
# City is not found. Skipping...
# Processing Record 33 of Set 4 | kudahuvadhoo
# Processing Record 34 of Set 4 | riyadh
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | inhambane
# Processing Record 37 of Set 4 | louisbourg
# City is not found. Skipping...
# Processing Record 38 of Set 4 | amderma
# City is not found. Skipping...
# Processing Record 39 of Set 4 | lebu
# Processing Record 40 of Set 4 | maniitsoq
# Processing Record 41 of Set 4 | tanout
# Processing Record 42 of Set 4 | bonavista
# Processing Record 43 of Set 4 | inirida
# Processing Record 44 of Set 4 | baldone
# Processing Record 45 of Set 4 | jalu
# Processing Record 46 of Set 4 | praya
# Processing Record 47 of Set 4 | luderitz
# Processing Record 48 of Set 4 | ponta do sol
# Processing Record 49 of Set 4 | san rafael
# Processing Record 50 of Set 4 | mahebourg
# Processing Record 1 of Set 5 | jiuquan
# Processing Record 2 of Set 5 | te anau
# Processing Record 3 of Set 5 | macamic
# Processing Record 4 of Set 5 | saint-pierre
# Processing Record 5 of Set 5 | honningsvag
# Processing Record 6 of Set 5 | cooma
# Processing Record 7 of Set 5 | smithers
# Processing Record 8 of Set 5 | bulancak
# Processing Record 9 of Set 5 | padang
# Processing Record 10 of Set 5 | banikoara
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | barcelos
# Processing Record 13 of Set 5 | ternate
# Processing Record 14 of Set 5 | mao
# Processing Record 15 of Set 5 | nikolskoye
# Processing Record 16 of Set 5 | amapa
# Processing Record 17 of Set 5 | manzhouli
# Processing Record 18 of Set 5 | mehamn
# Processing Record 19 of Set 5 | hakodate
# Processing Record 20 of Set 5 | ukiah
# Processing Record 21 of Set 5 | belushya guba
# City is not found. Skipping...
# Processing Record 22 of Set 5 | souillac
# Processing Record 23 of Set 5 | tessalit
# Processing Record 24 of Set 5 | fortuna
# Processing Record 25 of Set 5 | tawkar
# City is not found. Skipping...
# Processing Record 26 of Set 5 | tumannyy
# City is not found. Skipping...
# Processing Record 27 of Set 5 | tiksi
# Processing Record 28 of Set 5 | poum
# Processing Record 29 of Set 5 | mathbaria
# Processing Record 30 of Set 5 | katsuura
# Processing Record 31 of Set 5 | shimoda
# Processing Record 32 of Set 5 | leh
# Processing Record 33 of Set 5 | karabuk
# Processing Record 34 of Set 5 | bambari
# Processing Record 35 of Set 5 | maracaju
# Processing Record 36 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 5 | sholapur
# Processing Record 38 of Set 5 | dingle
# Processing Record 39 of Set 5 | belaya gora
# Processing Record 40 of Set 5 | muros
# Processing Record 41 of Set 5 | along
# Processing Record 42 of Set 5 | avera
# Processing Record 43 of Set 5 | diamantino
# Processing Record 44 of Set 5 | flagstaff
# Processing Record 45 of Set 5 | gravdal
# Processing Record 46 of Set 5 | goderich
# Processing Record 47 of Set 5 | ulladulla
# Processing Record 48 of Set 5 | ulcinj
# Processing Record 49 of Set 5 | fray bentos
# Processing Record 50 of Set 5 | state college
# Processing Record 1 of Set 6 | aracoiaba
# Processing Record 2 of Set 6 | civitavecchia
# Processing Record 3 of Set 6 | dimitrovgrad
# Processing Record 4 of Set 6 | west wendover
# Processing Record 5 of Set 6 | inta
# Processing Record 6 of Set 6 | riachao
# Processing Record 7 of Set 6 | lavrentiya
# Processing Record 8 of Set 6 | buala
# Processing Record 9 of Set 6 | trelew
# Processing Record 10 of Set 6 | valdivia
# Processing Record 11 of Set 6 | cayenne
# Processing Record 12 of Set 6 | san antonio
# Processing Record 13 of Set 6 | obihiro
# Processing Record 14 of Set 6 | sao filipe
# Processing Record 15 of Set 6 | longyearbyen
# Processing Record 16 of Set 6 | catamarca
# Processing Record 17 of Set 6 | mbekenyera
# Processing Record 18 of Set 6 | northam
# Processing Record 19 of Set 6 | sotouboua
# Processing Record 20 of Set 6 | sungairaya
# Processing Record 21 of Set 6 | hamilton
# Processing Record 22 of Set 6 | visby
# Processing Record 23 of Set 6 | port hardy
# Processing Record 24 of Set 6 | hobyo
# Processing Record 25 of Set 6 | lompoc
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | calvia
# Processing Record 28 of Set 6 | margate
# Processing Record 29 of Set 6 | san policarpo
# Processing Record 30 of Set 6 | nouadhibou
# Processing Record 31 of Set 6 | carlentini
# Processing Record 32 of Set 6 | phan thiet
# Processing Record 33 of Set 6 | tabialan
# City is not found. Skipping...
# Processing Record 34 of Set 6 | wamba
# Processing Record 35 of Set 6 | dargaville
# Processing Record 36 of Set 6 | marovoay
# Processing Record 37 of Set 6 | ribas do rio pardo
# Processing Record 38 of Set 6 | grand river south east
# City is not found. Skipping...
# Processing Record 39 of Set 6 | kyren
# Processing Record 40 of Set 6 | imbituba
# Processing Record 41 of Set 6 | mollendo
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | touros
# Processing Record 44 of Set 6 | ivanovka
# Processing Record 45 of Set 6 | farafangana
# Processing Record 46 of Set 6 | rungata
# City is not found. Skipping...
# Processing Record 47 of Set 6 | sjenica
# Processing Record 48 of Set 6 | ketchikan
# Processing Record 49 of Set 6 | igrim
# Processing Record 50 of Set 6 | thinadhoo
# Processing Record 1 of Set 7 | kodiak
# Processing Record 2 of Set 7 | hervey bay
# Processing Record 3 of Set 7 | bowen
# Processing Record 4 of Set 7 | frankfort
# Processing Record 5 of Set 7 | egvekinot
# Processing Record 6 of Set 7 | presidencia roque saenz pena
# Processing Record 7 of Set 7 | chuguyevka
# Processing Record 8 of Set 7 | mizdah
# Processing Record 9 of Set 7 | doctor pedro p. pena
# City is not found. Skipping...
# Processing Record 10 of Set 7 | klyuchi
# Processing Record 11 of Set 7 | chaman
# Processing Record 12 of Set 7 | negombo
# Processing Record 13 of Set 7 | georgiyevka
# Processing Record 14 of Set 7 | grindavik
# Processing Record 15 of Set 7 | ouallam
# Processing Record 16 of Set 7 | arlit
# Processing Record 17 of Set 7 | tan an
# Processing Record 18 of Set 7 | nome
# Processing Record 19 of Set 7 | trincomalee
# Processing Record 20 of Set 7 | preobrazheniye
# Processing Record 21 of Set 7 | kassala
# Processing Record 22 of Set 7 | yanam
# Processing Record 23 of Set 7 | the valley
# Processing Record 24 of Set 7 | rawson
# Processing Record 25 of Set 7 | sentyabrskiy
# City is not found. Skipping...
# Processing Record 26 of Set 7 | lorengau
# Processing Record 27 of Set 7 | dalvik
# Processing Record 28 of Set 7 | general roca
# Processing Record 29 of Set 7 | walvis bay
# Processing Record 30 of Set 7 | san francisco
# Processing Record 31 of Set 7 | cervo
# Processing Record 32 of Set 7 | chuy
# Processing Record 33 of Set 7 | yuanping
# Processing Record 34 of Set 7 | shatsk
# Processing Record 35 of Set 7 | vardo
# Processing Record 36 of Set 7 | safaga
# Processing Record 37 of Set 7 | tabiauea
# City is not found. Skipping...
# Processing Record 38 of Set 7 | veraval
# Processing Record 39 of Set 7 | san patricio
# Processing Record 40 of Set 7 | acapulco
# Processing Record 41 of Set 7 | ust-maya
# Processing Record 42 of Set 7 | kupang
# Processing Record 43 of Set 7 | malakal
# Processing Record 44 of Set 7 | rocha
# Processing Record 45 of Set 7 | lahij
# Processing Record 46 of Set 7 | tual
# Processing Record 47 of Set 7 | kizilskoye
# Processing Record 48 of Set 7 | codrington
# Processing Record 49 of Set 7 | bud
# Processing Record 50 of Set 7 | panguna
# Processing Record 1 of Set 8 | sari
# Processing Record 2 of Set 8 | zachagansk
# City is not found. Skipping...
# Processing Record 3 of Set 8 | ugoofaaru
# Processing Record 4 of Set 8 | zavodskoy
# Processing Record 5 of Set 8 | grand gaube
# Processing Record 6 of Set 8 | santa fe
# Processing Record 7 of Set 8 | rio gallegos
# Processing Record 8 of Set 8 | yabrud
# Processing Record 9 of Set 8 | svetlyy
# Processing Record 10 of Set 8 | klaksvik
# Processing Record 11 of Set 8 | koslan
# Processing Record 12 of Set 8 | chagda
# City is not found. Skipping...
# Processing Record 13 of Set 8 | srivardhan
# Processing Record 14 of Set 8 | tateyama
# Processing Record 15 of Set 8 | glace bay
# Processing Record 16 of Set 8 | sabzevar
# Processing Record 17 of Set 8 | karratha
# Processing Record 18 of Set 8 | viligili
# City is not found. Skipping...
# Processing Record 19 of Set 8 | winsum
# Processing Record 20 of Set 8 | pitimbu
# Processing Record 21 of Set 8 | mahanoro
# Processing Record 22 of Set 8 | bardiyah
# Processing Record 23 of Set 8 | makakilo city
# Processing Record 24 of Set 8 | paamiut
# Processing Record 25 of Set 8 | malinovoye ozero
# Processing Record 26 of Set 8 | pochutla
# Processing Record 27 of Set 8 | sidney
# Processing Record 28 of Set 8 | alenquer
# Processing Record 29 of Set 8 | penzance
# Processing Record 30 of Set 8 | ushumun
# Processing Record 31 of Set 8 | mitu
# Processing Record 32 of Set 8 | bugama
# Processing Record 33 of Set 8 | zemio
# Processing Record 34 of Set 8 | ayagoz
# Processing Record 35 of Set 8 | dunda
# Processing Record 36 of Set 8 | ashtabula
# Processing Record 37 of Set 8 | bitung
# Processing Record 38 of Set 8 | tartagal
# Processing Record 39 of Set 8 | anadyr
# Processing Record 40 of Set 8 | verkhnevilyuysk
# Processing Record 41 of Set 8 | madimba
# Processing Record 42 of Set 8 | newport
# Processing Record 43 of Set 8 | pimenta bueno
# Processing Record 44 of Set 8 | katobu
# Processing Record 45 of Set 8 | dzaoudzi
# Processing Record 46 of Set 8 | kiama
# Processing Record 47 of Set 8 | hay river
# Processing Record 48 of Set 8 | bulgan
# Processing Record 49 of Set 8 | levin
# Processing Record 50 of Set 8 | fairbanks
# Processing Record 1 of Set 9 | staryy nadym
# Processing Record 2 of Set 9 | moshenskoye
# Processing Record 3 of Set 9 | kaeo
# Processing Record 4 of Set 9 | cabo san lucas
# Processing Record 5 of Set 9 | barra do bugres
# Processing Record 6 of Set 9 | kenai
# Processing Record 7 of Set 9 | ocampo
# Processing Record 8 of Set 9 | katherine
# Processing Record 9 of Set 9 | plouzane
# Processing Record 10 of Set 9 | caucaia
# Processing Record 11 of Set 9 | pontes e lacerda
# Processing Record 12 of Set 9 | puerto escondido
# Processing Record 13 of Set 9 | warri
# Processing Record 14 of Set 9 | alta floresta
# Processing Record 15 of Set 9 | green river
# Processing Record 16 of Set 9 | buchanan
# Processing Record 17 of Set 9 | olafsvik
# Processing Record 18 of Set 9 | buin
# Processing Record 19 of Set 9 | sobolevo
# Processing Record 20 of Set 9 | methoni
# Processing Record 21 of Set 9 | clarksburg
# Processing Record 22 of Set 9 | cockburn town
# Processing Record 23 of Set 9 | nizwa
# Processing Record 24 of Set 9 | george
# Processing Record 25 of Set 9 | zhigansk
# Processing Record 26 of Set 9 | aasiaat
# Processing Record 27 of Set 9 | sinkat
# City is not found. Skipping...
# Processing Record 28 of Set 9 | sitka
# Processing Record 29 of Set 9 | ahipara
# Processing Record 30 of Set 9 | zabol
# Processing Record 31 of Set 9 | formoso do araguaia
# City is not found. Skipping...
# Processing Record 32 of Set 9 | santa maria
# Processing Record 33 of Set 9 | mangan
# Processing Record 34 of Set 9 | geresk
# City is not found. Skipping...
# Processing Record 35 of Set 9 | nizhniy kuranakh
# Processing Record 36 of Set 9 | churapcha
# Processing Record 37 of Set 9 | wellsford
# Processing Record 38 of Set 9 | takaka
# Processing Record 39 of Set 9 | puerto ayacucho
# Processing Record 40 of Set 9 | saldanha
# Processing Record 41 of Set 9 | naze
# Processing Record 42 of Set 9 | kedrovyy
# Processing Record 43 of Set 9 | cabedelo
# Processing Record 44 of Set 9 | sambava
# Processing Record 45 of Set 9 | berlevag
# Processing Record 46 of Set 9 | sibolga
# Processing Record 47 of Set 9 | santa eulalia
# Processing Record 48 of Set 9 | necochea
# Processing Record 49 of Set 9 | falun
# Processing Record 50 of Set 9 | marquette
# Processing Record 1 of Set 10 | naples
# Processing Record 2 of Set 10 | matagami
# Processing Record 3 of Set 10 | san cristobal
# Processing Record 4 of Set 10 | kurchum
# Processing Record 5 of Set 10 | price
# Processing Record 6 of Set 10 | rapar
# Processing Record 7 of Set 10 | nguiu
# City is not found. Skipping...
# Processing Record 8 of Set 10 | tecpatan
# Processing Record 9 of Set 10 | voyvozh
# Processing Record 10 of Set 10 | lagodekhi
# Processing Record 11 of Set 10 | coarnele caprei
# Processing Record 12 of Set 10 | berezovyy
# Processing Record 13 of Set 10 | magdiwang
# Processing Record 14 of Set 10 | nguru
# Processing Record 15 of Set 10 | swan hill
# Processing Record 16 of Set 10 | mackay
# Processing Record 17 of Set 10 | inyonga
# Processing Record 18 of Set 10 | tara
# Processing Record 19 of Set 10 | kaseda
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | terrace
# Processing Record 22 of Set 10 | marzuq
# Processing Record 23 of Set 10 | villa del rosario
# Processing Record 24 of Set 10 | edson
# Processing Record 25 of Set 10 | mae sai
# Processing Record 26 of Set 10 | sola
# Processing Record 27 of Set 10 | dera bugti
# Processing Record 28 of Set 10 | hopkinsville
# Processing Record 29 of Set 10 | kristianstad
# Processing Record 30 of Set 10 | meulaboh
# Processing Record 31 of Set 10 | zhezkazgan
# Processing Record 32 of Set 10 | noyakert
# Processing Record 33 of Set 10 | the pas
# Processing Record 34 of Set 10 | valparaiso
# Processing Record 35 of Set 10 | namibe
# Processing Record 36 of Set 10 | moerai
# Processing Record 37 of Set 10 | jumilla
# Processing Record 38 of Set 10 | zonguldak
# Processing Record 39 of Set 10 | moose factory
# Processing Record 40 of Set 10 | road town
# Processing Record 41 of Set 10 | celestun
# Processing Record 42 of Set 10 | paratebueno
# Processing Record 43 of Set 10 | halalo
# City is not found. Skipping...
# Processing Record 44 of Set 10 | kayerkan
# Processing Record 45 of Set 10 | aitape
# Processing Record 46 of Set 10 | disna
# Processing Record 47 of Set 10 | talnakh
# Processing Record 48 of Set 10 | ponta delgada
# Processing Record 49 of Set 10 | valsamata
# Processing Record 50 of Set 10 | malanje
# Processing Record 1 of Set 11 | rabo de peixe
# Processing Record 2 of Set 11 | neyyattinkara
# Processing Record 3 of Set 11 | seoul
# Processing Record 4 of Set 11 | bad durkheim
# Processing Record 5 of Set 11 | saryshagan
# City is not found. Skipping...
# Processing Record 6 of Set 11 | ye
# City is not found. Skipping...
# Processing Record 7 of Set 11 | cardedeu
# Processing Record 8 of Set 11 | samalaeulu
# City is not found. Skipping...
# Processing Record 9 of Set 11 | labutta
# City is not found. Skipping...
# Processing Record 10 of Set 11 | pechenga
# Processing Record 11 of Set 11 | wa
# City is not found. Skipping...
# Processing Record 12 of Set 11 | richards bay
# Processing Record 13 of Set 11 | mizque
# Processing Record 14 of Set 11 | lovozero
# Processing Record 15 of Set 11 | iralaya
# Processing Record 16 of Set 11 | gonzaga
# Processing Record 17 of Set 11 | marienburg
# Processing Record 18 of Set 11 | urubicha
# Processing Record 19 of Set 11 | dergachi
# Processing Record 20 of Set 11 | byron bay
# Processing Record 21 of Set 11 | nara
# Processing Record 22 of Set 11 | pandan
# Processing Record 23 of Set 11 | haputale
# Processing Record 24 of Set 11 | roma
# Processing Record 25 of Set 11 | shupiyan
# Processing Record 26 of Set 11 | skjervoy
# Processing Record 27 of Set 11 | mezen
# Processing Record 28 of Set 11 | taksimo
# Processing Record 29 of Set 11 | poronaysk
# Processing Record 30 of Set 11 | oussouye
# Processing Record 31 of Set 11 | warqla
# City is not found. Skipping...
# Processing Record 32 of Set 11 | terra santa
# Processing Record 33 of Set 11 | guerrero negro
# Processing Record 34 of Set 11 | meadow lake
# Processing Record 35 of Set 11 | wairoa
# Processing Record 36 of Set 11 | mansa
# Processing Record 37 of Set 11 | baldeogarh
# Processing Record 38 of Set 11 | lahad datu
# Processing Record 39 of Set 11 | quang ngai
# Processing Record 40 of Set 11 | aksha
# Processing Record 41 of Set 11 | saint combs
# City is not found. Skipping...
# Processing Record 42 of Set 11 | paragominas
# Processing Record 43 of Set 11 | matamoros
# Processing Record 44 of Set 11 | cherskiy
# Processing Record 45 of Set 11 | aleksandrovskoye
# Processing Record 46 of Set 11 | coffs harbour
# Processing Record 47 of Set 11 | tocopilla
# Processing Record 48 of Set 11 | antalaha
# Processing Record 49 of Set 11 | wasilla
# Processing Record 50 of Set 11 | berestechko
# Processing Record 1 of Set 12 | sanford
# Processing Record 2 of Set 12 | crotone
# Processing Record 3 of Set 12 | udachnyy
# Processing Record 4 of Set 12 | nhulunbuy
# Processing Record 5 of Set 12 | saint pete beach
# Processing Record 6 of Set 12 | trairi
# Processing Record 7 of Set 12 | gallup
# Processing Record 8 of Set 12 | salalah
# Processing Record 9 of Set 12 | sapa
# Processing Record 10 of Set 12 | naenwa
# City is not found. Skipping...
# Processing Record 11 of Set 12 | garden city
# Processing Record 12 of Set 12 | jadu
# Processing Record 13 of Set 12 | ardakan
# Processing Record 14 of Set 12 | bathsheba
# Processing Record 15 of Set 12 | abong mbang
# Processing Record 16 of Set 12 | laguna
# Processing Record 17 of Set 12 | svetlaya
# Processing Record 18 of Set 12 | gorontalo
# Processing Record 19 of Set 12 | aguie
# Processing Record 20 of Set 12 | concarneau
# Processing Record 21 of Set 12 | atka
# City is not found. Skipping...
# Processing Record 22 of Set 12 | phan rang
# City is not found. Skipping...
# Processing Record 23 of Set 12 | tanshui
# City is not found. Skipping...
# Processing Record 24 of Set 12 | tura
# Processing Record 25 of Set 12 | barahona
# Processing Record 26 of Set 12 | sanmenxia
# Processing Record 27 of Set 12 | nantucket
# Processing Record 28 of Set 12 | eufaula
# Processing Record 29 of Set 12 | colinas
# Processing Record 30 of Set 12 | tahe
# Processing Record 31 of Set 12 | clarence town
# Processing Record 32 of Set 12 | dunedin
# Processing Record 33 of Set 12 | tacuarembo
# Processing Record 34 of Set 12 | ola
# Processing Record 35 of Set 12 | saint-pacome
# City is not found. Skipping...
# Processing Record 36 of Set 12 | truckee
# Processing Record 37 of Set 12 | rio de janeiro
# Processing Record 38 of Set 12 | tarudant
# City is not found. Skipping...
# Processing Record 39 of Set 12 | korla
# Processing Record 40 of Set 12 | north bend
# Processing Record 41 of Set 12 | wisconsin rapids
# Processing Record 42 of Set 12 | xinglongshan
# Processing Record 43 of Set 12 | tilichiki
# Processing Record 44 of Set 12 | mardin
# Processing Record 45 of Set 12 | lima
# Processing Record 46 of Set 12 | villa carlos paz
# Processing Record 47 of Set 12 | ciudad bolivar
# Processing Record 48 of Set 12 | deputatskiy
# Processing Record 49 of Set 12 | gurupi
# Processing Record 50 of Set 12 | ginda
# Processing Record 1 of Set 13 | la libertad
# Processing Record 2 of Set 13 | sorong
# Processing Record 3 of Set 13 | barbar
# City is not found. Skipping...
# Processing Record 4 of Set 13 | davila
# Processing Record 5 of Set 13 | xianshuigu
# Processing Record 6 of Set 13 | kissidougou
# Processing Record 7 of Set 13 | carballo
# Processing Record 8 of Set 13 | saint-georges
# Processing Record 9 of Set 13 | aketi
# Processing Record 10 of Set 13 | kalangala
# Processing Record 11 of Set 13 | nizhniy tsasuchey
# Processing Record 12 of Set 13 | iberia
# Processing Record 13 of Set 13 | sibu
# Processing Record 14 of Set 13 | caronport
# Processing Record 15 of Set 13 | eenhana
# Processing Record 16 of Set 13 | kulunda
# Processing Record 17 of Set 13 | boa vista
# Processing Record 18 of Set 13 | comodoro rivadavia
# Processing Record 19 of Set 13 | srednekolymsk
# Processing Record 20 of Set 13 | shimonoseki
# Processing Record 21 of Set 13 | san jeronimo
# Processing Record 22 of Set 13 | salinopolis
# Processing Record 23 of Set 13 | orocue
# Processing Record 24 of Set 13 | saint-augustin
# Processing Record 25 of Set 13 | koutiala
# Processing Record 26 of Set 13 | omboue
# Processing Record 27 of Set 13 | changping
# Processing Record 28 of Set 13 | tsabong
# Processing Record 29 of Set 13 | nuuk
# Processing Record 30 of Set 13 | ust-kamchatsk
# City is not found. Skipping...
# Processing Record 31 of Set 13 | puerto baquerizo moreno
# Processing Record 32 of Set 13 | quatre cocos
# Processing Record 33 of Set 13 | aljezur
# Processing Record 34 of Set 13 | faya
# Processing Record 35 of Set 13 | sindon
# Processing Record 36 of Set 13 | camacupa
# Processing Record 37 of Set 13 | turki
# Processing Record 38 of Set 13 | santa isabel do rio negro
# Processing Record 39 of Set 13 | morehead
# Processing Record 40 of Set 13 | samoded
# Processing Record 41 of Set 13 | san vicente
# Processing Record 42 of Set 13 | mareeba
# Processing Record 43 of Set 13 | kimbe
# Processing Record 44 of Set 13 | sinjar
# Processing Record 45 of Set 13 | kahului
# Processing Record 46 of Set 13 | serra
# Processing Record 47 of Set 13 | kazalinsk
# City is not found. Skipping...
# Processing Record 48 of Set 13 | kamenskoye
# City is not found. Skipping...
# Processing Record 49 of Set 13 | olinda
# Processing Record 50 of Set 13 | kuching
# Processing Record 1 of Set 14 | naftah
# City is not found. Skipping...
# Processing Record 2 of Set 14 | sherpur
# Processing Record 3 of Set 14 | komsomolskiy
# Processing Record 4 of Set 14 | basco
# Processing Record 5 of Set 14 | fare
# Processing Record 6 of Set 14 | matara
# Processing Record 7 of Set 14 | prnjavor
# Processing Record 8 of Set 14 | biltine
# Processing Record 9 of Set 14 | bolungarvik
# City is not found. Skipping...
# Processing Record 10 of Set 14 | waynesville
# Processing Record 11 of Set 14 | mayo
# Processing Record 12 of Set 14 | westport
# Processing Record 13 of Set 14 | eskasem
# City is not found. Skipping...
# Processing Record 14 of Set 14 | lubao
# Processing Record 15 of Set 14 | duluth
# Processing Record 16 of Set 14 | bam
# Processing Record 17 of Set 14 | ngukurr
# City is not found. Skipping...
# Processing Record 18 of Set 14 | shilovo
# Processing Record 19 of Set 14 | altar
# Processing Record 20 of Set 14 | boatlaname
# City is not found. Skipping...
# Processing Record 21 of Set 14 | nakhon si thammarat
# Processing Record 22 of Set 14 | sinnamary
# Processing Record 23 of Set 14 | port-gentil
# Processing Record 24 of Set 14 | lokken verk
# City is not found. Skipping...
# Processing Record 25 of Set 14 | orsk
# Processing Record 26 of Set 14 | kisaran
# Processing Record 27 of Set 14 | simoes
# Processing Record 28 of Set 14 | san quintin
# Processing Record 29 of Set 14 | seymchan
# Processing Record 30 of Set 14 | alabaster
# Processing Record 31 of Set 14 | uniao
# Processing Record 32 of Set 14 | qasigiannguit
# Processing Record 33 of Set 14 | portland
# Processing Record 34 of Set 14 | namatanai
# Processing Record 35 of Set 14 | sedelnikovo
# City is not found. Skipping...
# Processing Record 36 of Set 14 | kloulklubed
# Processing Record 37 of Set 14 | kodinsk
# Processing Record 38 of Set 14 | uwayl
# City is not found. Skipping...
# Processing Record 39 of Set 14 | konstantinovskiy
# Processing Record 40 of Set 14 | tabuk
# Processing Record 41 of Set 14 | abay
# Processing Record 42 of Set 14 | ancud
# Processing Record 43 of Set 14 | college
# Processing Record 44 of Set 14 | magadan
# Processing Record 45 of Set 14 | amos
# Processing Record 46 of Set 14 | gouyave
# Processing Record 47 of Set 14 | asau
# Processing Record 48 of Set 14 | port hedland
# Processing Record 49 of Set 14 | arman
# Processing Record 50 of Set 14 | masallatah
# Processing Record 1 of Set 15 | dustlik
# Processing Record 2 of Set 15 | tuy hoa
# Processing Record 3 of Set 15 | pangoa
# Processing Record 4 of Set 15 | tonantins
# Processing Record 5 of Set 15 | ulaangom
# Processing Record 6 of Set 15 | pemangkat
# Processing Record 7 of Set 15 | ayan
# Processing Record 8 of Set 15 | broken hill
# Processing Record 9 of Set 15 | zachepylivka
# Processing Record 10 of Set 15 | auka
# Processing Record 11 of Set 15 | andenes
# Processing Record 12 of Set 15 | osakarovka
# Processing Record 13 of Set 15 | touho
# Processing Record 14 of Set 15 | mishelevka
# Processing Record 15 of Set 15 | kyabe
# Processing Record 16 of Set 15 | pryluky
# Processing Record 17 of Set 15 | zyryanka
# Processing Record 18 of Set 15 | lubango
# Processing Record 19 of Set 15 | turtas
# Processing Record 20 of Set 15 | saleaula
# City is not found. Skipping...
# Processing Record 21 of Set 15 | abu kamal
# Processing Record 22 of Set 15 | raahe
# Processing Record 23 of Set 15 | yeppoon
# Processing Record 24 of Set 15 | dosso
# Processing Record 25 of Set 15 | robat karim
# Processing Record 26 of Set 15 | chitral
# Processing Record 27 of Set 15 | bontang
# Processing Record 28 of Set 15 | mbandaka
# Processing Record 29 of Set 15 | warrnambool
# Processing Record 30 of Set 15 | malacacheta
# Processing Record 31 of Set 15 | jahrom
# City is not found. Skipping...
# Processing Record 32 of Set 15 | ballina
# Processing Record 33 of Set 15 | ostrovnoy
# Processing Record 34 of Set 15 | ampanihy
# Processing Record 35 of Set 15 | port augusta
# Processing Record 36 of Set 15 | toktogul
# Processing Record 37 of Set 15 | lalomanu
# City is not found. Skipping...
# Processing Record 38 of Set 15 | tecoanapa
# Processing Record 39 of Set 15 | bereda
# Processing Record 40 of Set 15 | voh
# Processing Record 41 of Set 15 | carutapera
# Processing Record 42 of Set 15 | okhotsk
# Processing Record 43 of Set 15 | soddy-daisy
# Processing Record 44 of Set 15 | nurlat
# Processing Record 45 of Set 15 | pangody
# Processing Record 46 of Set 15 | lukovetskiy
# Processing Record 47 of Set 15 | shaunavon
# Processing Record 48 of Set 15 | yelets
# Processing Record 49 of Set 15 | xadani
# City is not found. Skipping...
# Processing Record 50 of Set 15 | bela
# Processing Record 1 of Set 16 | bulungu
# Processing Record 2 of Set 16 | fukue
# Processing Record 3 of Set 16 | vanavara
# Processing Record 4 of Set 16 | umm kaddadah
# Processing Record 5 of Set 16 | teguldet
# Processing Record 6 of Set 16 | axim
# Processing Record 7 of Set 16 | ozernovskiy
# Processing Record 8 of Set 16 | marcona
# City is not found. Skipping...
# Processing Record 9 of Set 16 | tokzar
# City is not found. Skipping...
# Processing Record 10 of Set 16 | mwinilunga
# Processing Record 11 of Set 16 | sassandra
# Processing Record 12 of Set 16 | sakaiminato
# Processing Record 13 of Set 16 | maricka
# Processing Record 14 of Set 16 | umzimvubu
# City is not found. Skipping...
# Processing Record 15 of Set 16 | hagere selam
# Processing Record 16 of Set 16 | pala
# Processing Record 17 of Set 16 | peniche
# Processing Record 18 of Set 16 | cairns
# Processing Record 19 of Set 16 | nelson bay
# Processing Record 20 of Set 16 | kuna
# Processing Record 21 of Set 16 | haines junction
# Processing Record 22 of Set 16 | lodwar
# Processing Record 23 of Set 16 | macenta
# Processing Record 24 of Set 16 | jaguaruna
# Processing Record 25 of Set 16 | nanakuli
# Processing Record 26 of Set 16 | wajima
# Processing Record 27 of Set 16 | gainesville
# Processing Record 28 of Set 16 | mount gambier
# Processing Record 29 of Set 16 | sayyan
# Processing Record 30 of Set 16 | okandja
# City is not found. Skipping...
# Processing Record 31 of Set 16 | paris
# Processing Record 32 of Set 16 | atar
# Processing Record 33 of Set 16 | ayer itam
# City is not found. Skipping...
# Processing Record 34 of Set 16 | zomin
# Processing Record 35 of Set 16 | juneau
# Processing Record 36 of Set 16 | antofagasta
# Processing Record 37 of Set 16 | cape canaveral
# Processing Record 38 of Set 16 | oxbow
# Processing Record 39 of Set 16 | savannah bight
# Processing Record 40 of Set 16 | misratah
# Processing Record 41 of Set 16 | gushikawa
# Processing Record 42 of Set 16 | luzhou
# Processing Record 43 of Set 16 | kuusamo
# Processing Record 44 of Set 16 | rock sound
# Processing Record 45 of Set 16 | kampot
# Processing Record 46 of Set 16 | wladyslawowo
# Processing Record 47 of Set 16 | kapoeta
# Processing Record 48 of Set 16 | tadine
# Processing Record 49 of Set 16 | bassano
# Processing Record 50 of Set 16 | bangad
# Processing Record 1 of Set 17 | jiddah
# City is not found. Skipping...
# Processing Record 2 of Set 17 | deh rawud
# City is not found. Skipping...
# Processing Record 3 of Set 17 | narbonne
# Processing Record 4 of Set 17 | gorno-chuyskiy
# City is not found. Skipping...
# Processing Record 5 of Set 17 | esil
# Processing Record 6 of Set 17 | ormoz
# Processing Record 7 of Set 17 | vila
# Processing Record 8 of Set 17 | kashi
# Processing Record 9 of Set 17 | hami
# Processing Record 10 of Set 17 | yumen
# Processing Record 11 of Set 17 | neuquen
# Processing Record 12 of Set 17 | den helder
# Processing Record 13 of Set 17 | mirandopolis
# Processing Record 14 of Set 17 | marsa matruh
# Processing Record 15 of Set 17 | riohacha
# Processing Record 16 of Set 17 | bose
# Processing Record 17 of Set 17 | lerwick
# Processing Record 18 of Set 17 | bisho
# Processing Record 19 of Set 17 | molchanovo
# Processing Record 20 of Set 17 | miandrivazo
# Processing Record 21 of Set 17 | mrakovo
# Processing Record 22 of Set 17 | mahon
# Processing Record 23 of Set 17 | senmonorom
# City is not found. Skipping...
# Processing Record 24 of Set 17 | cururupu
# Processing Record 25 of Set 17 | bereznik
# Processing Record 26 of Set 17 | acandi
# Processing Record 27 of Set 17 | bubaque
# Processing Record 28 of Set 17 | cap malheureux
# Processing Record 29 of Set 17 | san lorenzo
# Processing Record 30 of Set 17 | jacareacanga
# Processing Record 31 of Set 17 | urengoy
# Processing Record 32 of Set 17 | krasnoselkup
# Processing Record 33 of Set 17 | sioux lookout
# Processing Record 34 of Set 17 | boshan
# Processing Record 35 of Set 17 | mecca
# Processing Record 36 of Set 17 | taltal
# Processing Record 37 of Set 17 | joshimath
# Processing Record 38 of Set 17 | vestmannaeyjar
# Processing Record 39 of Set 17 | consuegra
# Processing Record 40 of Set 17 | la ronge
# Processing Record 41 of Set 17 | nadym
# Processing Record 42 of Set 17 | qaqortoq
# Processing Record 43 of Set 17 | barmstedt
# Processing Record 44 of Set 17 | mundo nuevo
# Processing Record 45 of Set 17 | kholodnyy
# Processing Record 46 of Set 17 | hendersonville
# Processing Record 47 of Set 17 | sundumbili
# Processing Record 48 of Set 17 | ambon
# Processing Record 49 of Set 17 | crab hill
# City is not found. Skipping...
# Processing Record 50 of Set 17 | tomatlan
# Processing Record 1 of Set 18 | katiola
# Processing Record 2 of Set 18 | hai phong
# City is not found. Skipping...
# Processing Record 3 of Set 18 | jeremie
# Processing Record 4 of Set 18 | bilma
# Processing Record 5 of Set 18 | floro
# Processing Record 6 of Set 18 | alofi
# Processing Record 7 of Set 18 | yalchiki
# City is not found. Skipping...
# Processing Record 8 of Set 18 | ambilobe
# Processing Record 9 of Set 18 | huarmey
# Processing Record 10 of Set 18 | chitipa
# Processing Record 11 of Set 18 | barth
# Processing Record 12 of Set 18 | tarabuco
# Processing Record 13 of Set 18 | san juan
# Processing Record 14 of Set 18 | malwan
# City is not found. Skipping...
# Processing Record 15 of Set 18 | bandarbeyla
# Processing Record 16 of Set 18 | atherton
# Processing Record 17 of Set 18 | verkhnyaya toyma
# Processing Record 18 of Set 18 | dennery
# Processing Record 19 of Set 18 | oskaloosa
# Processing Record 20 of Set 18 | at-bashi
# Processing Record 21 of Set 18 | zhanaozen
# Processing Record 22 of Set 18 | kushiro
# Processing Record 23 of Set 18 | tsienyane
# City is not found. Skipping...
# Processing Record 24 of Set 18 | panaba
# Processing Record 25 of Set 18 | itarema
# Processing Record 26 of Set 18 | honiara
# Processing Record 27 of Set 18 | sfantu gheorghe
# Processing Record 28 of Set 18 | pelym
# Processing Record 29 of Set 18 | mys shmidta
# City is not found. Skipping...
# Processing Record 30 of Set 18 | concepcion del oro
# Processing Record 31 of Set 18 | alugan
# Processing Record 32 of Set 18 | angouleme
# Processing Record 33 of Set 18 | hasaki
# Processing Record 34 of Set 18 | maghama
# City is not found. Skipping...
# Processing Record 35 of Set 18 | palabuhanratu
# City is not found. Skipping...
# Processing Record 36 of Set 18 | bukama
# Processing Record 37 of Set 18 | zapolyarnyy
# Processing Record 38 of Set 18 | lata
# Processing Record 39 of Set 18 | vilhena
# Processing Record 40 of Set 18 | santo antonio do ica
# Processing Record 41 of Set 18 | pacasmayo
# Processing Record 42 of Set 18 | tautira
# Processing Record 43 of Set 18 | marfino
# Processing Record 44 of Set 18 | edd
# Processing Record 45 of Set 18 | copiapo
# Processing Record 46 of Set 18 | henties bay
# Processing Record 47 of Set 18 | kalmunai
# Processing Record 48 of Set 18 | dhanera
# Processing Record 49 of Set 18 | hakone
# Processing Record 50 of Set 18 | viedma
# Processing Record 1 of Set 19 | kasane
# Processing Record 2 of Set 19 | puerto palomas
# Processing Record 3 of Set 19 | bourail
# Processing Record 4 of Set 19 | zhangjiakou
# Processing Record 5 of Set 19 | marsala
# Processing Record 6 of Set 19 | tungor
# Processing Record 7 of Set 19 | san-pedro
# Processing Record 8 of Set 19 | sao joao da barra
# Processing Record 9 of Set 19 | turinskaya sloboda
# Processing Record 10 of Set 19 | broome
# Processing Record 11 of Set 19 | toropets
# Processing Record 12 of Set 19 | vostok
# Processing Record 13 of Set 19 | jabiru
# City is not found. Skipping...
# Processing Record 14 of Set 19 | kabare
# Processing Record 15 of Set 19 | dilla
# Processing Record 16 of Set 19 | gundlupet
# Processing Record 17 of Set 19 | mujiayingzi
# Processing Record 18 of Set 19 | caico
# Processing Record 19 of Set 19 | popondetta
# Processing Record 20 of Set 19 | karkaralinsk
# City is not found. Skipping...
# Processing Record 21 of Set 19 | gisborne
# Processing Record 22 of Set 19 | lensk
# Processing Record 23 of Set 19 | ravar
# Processing Record 24 of Set 19 | monte alegre
# Processing Record 25 of Set 19 | sokoto
# Processing Record 26 of Set 19 | stokmarknes
# Processing Record 27 of Set 19 | taman
# Processing Record 28 of Set 19 | glenwood springs
# Processing Record 29 of Set 19 | wagar
# Processing Record 30 of Set 19 | arkadelphia
# Processing Record 31 of Set 19 | thabazimbi
# Processing Record 32 of Set 19 | vrangel
# Processing Record 33 of Set 19 | gweta
# Processing Record 34 of Set 19 | beringovskiy
# Processing Record 35 of Set 19 | biloela
# Processing Record 36 of Set 19 | macaboboni
# City is not found. Skipping...
# Processing Record 37 of Set 19 | campagna
# Processing Record 38 of Set 19 | porto tolle
# Processing Record 39 of Set 19 | astana
# Processing Record 40 of Set 19 | flin flon
# Processing Record 41 of Set 19 | alyangula
# Processing Record 42 of Set 19 | aguada de pasajeros
# Processing Record 43 of Set 19 | hurup
# Processing Record 44 of Set 19 | chekhov
# Processing Record 45 of Set 19 | honggang
# Processing Record 46 of Set 19 | clyde river
# Processing Record 47 of Set 19 | bartoszyce
# Processing Record 48 of Set 19 | guayaramerin
# Processing Record 49 of Set 19 | hirara
# Processing Record 50 of Set 19 | gamboma
# Processing Record 1 of Set 20 | presque isle
# Processing Record 2 of Set 20 | wallaceburg
# Processing Record 3 of Set 20 | port keats
# Processing Record 4 of Set 20 | jipijapa
# Processing Record 5 of Set 20 | yulara
# Processing Record 6 of Set 20 | cuamba
# Processing Record 7 of Set 20 | baykit
# Processing Record 8 of Set 20 | aksu
# Processing Record 9 of Set 20 | chas
# Processing Record 10 of Set 20 | pitsunda
# Processing Record 11 of Set 20 | tabora
# Processing Record 12 of Set 20 | pingliang
# Processing Record 13 of Set 20 | khani
# Processing Record 14 of Set 20 | okahandja
# Processing Record 15 of Set 20 | christchurch
# Processing Record 16 of Set 20 | allapalli
# Processing Record 17 of Set 20 | moron
# Processing Record 18 of Set 20 | rawannawi
# City is not found. Skipping...
# Processing Record 19 of Set 20 | antsohihy
# Processing Record 20 of Set 20 | emerald
# Processing Record 21 of Set 20 | bocana de paiwas
# Processing Record 22 of Set 20 | sao miguel do araguaia
# Processing Record 23 of Set 20 | bosaso
# Processing Record 24 of Set 20 | wattegama
# Processing Record 25 of Set 20 | chitungwiza
# Processing Record 26 of Set 20 | san andres
# Processing Record 27 of Set 20 | burica
# City is not found. Skipping...
# Processing Record 28 of Set 20 | billings
# Processing Record 29 of Set 20 | wanning
# Processing Record 30 of Set 20 | arkhangelskoye
# Processing Record 31 of Set 20 | kumylzhenskaya
# Processing Record 32 of Set 20 | sungaipenuh
# Processing Record 33 of Set 20 | dabakala
# Processing Record 34 of Set 20 | clocolan
# Processing Record 35 of Set 20 | barentu
# Processing Record 36 of Set 20 | kondinskoye
# Processing Record 37 of Set 20 | mayor pablo lagerenza
# Processing Record 38 of Set 20 | liverpool
# Processing Record 39 of Set 20 | port shepstone
# Processing Record 40 of Set 20 | belmonte
# Processing Record 41 of Set 20 | harper
# Processing Record 42 of Set 20 | maceio
# Processing Record 43 of Set 20 | kuala terengganu
# Processing Record 44 of Set 20 | havelock
# Processing Record 45 of Set 20 | kanigiri
# Processing Record 46 of Set 20 | halmstad
# Processing Record 47 of Set 20 | nuevo progreso
# Processing Record 48 of Set 20 | umm durman
# City is not found. Skipping...
# Processing Record 49 of Set 20 | mahadday weyne
# City is not found. Skipping...
# Processing Record 50 of Set 20 | inongo
# Processing Record 1 of Set 21 | nokaneng
# Processing Record 2 of Set 21 | zambezi
# Processing Record 3 of Set 21 | husavik
# Processing Record 4 of Set 21 | miramar
# Processing Record 5 of Set 21 | bur gabo
# City is not found. Skipping...
# Processing Record 6 of Set 21 | onverwacht
# Processing Record 7 of Set 21 | aswan
# Processing Record 8 of Set 21 | viransehir
# Processing Record 9 of Set 21 | tezu
# Processing Record 10 of Set 21 | khasan
# Processing Record 11 of Set 21 | strelka
# Processing Record 12 of Set 21 | wawa
# Processing Record 13 of Set 21 | vangaindrano
# Processing Record 14 of Set 21 | mikkeli
# Processing Record 15 of Set 21 | kokopo
# Processing Record 16 of Set 21 | brae
# Processing Record 17 of Set 21 | totma
# Processing Record 18 of Set 21 | nichinan
# Processing Record 19 of Set 21 | castelo do piaui
# Processing Record 20 of Set 21 | olga
# Processing Record 21 of Set 21 | guildford
# Processing Record 22 of Set 21 | san rafael del sur
# Processing Record 23 of Set 21 | panguipulli
# Processing Record 24 of Set 21 | noumea
# Processing Record 25 of Set 21 | jatiroto
# Processing Record 26 of Set 21 | chimoio
# Processing Record 27 of Set 21 | kodinar
# Processing Record 28 of Set 21 | manacapuru
# Processing Record 29 of Set 21 | coahuayana
# Processing Record 30 of Set 21 | mana
# Processing Record 31 of Set 21 | verdun
# Processing Record 32 of Set 21 | eston
# Processing Record 33 of Set 21 | kokstad
# Processing Record 34 of Set 21 | of
# City is not found. Skipping...
# Processing Record 35 of Set 21 | locri
# Processing Record 36 of Set 21 | port macquarie
# Processing Record 37 of Set 21 | mananjary
# Processing Record 38 of Set 21 | tommot
# Processing Record 39 of Set 21 | eldikan
# City is not found. Skipping...
# Processing Record 40 of Set 21 | soyo
# Processing Record 41 of Set 21 | sangar
# Processing Record 42 of Set 21 | nioro
# Processing Record 43 of Set 21 | prince rupert
# Processing Record 44 of Set 21 | ludvika
# Processing Record 45 of Set 21 | heinola
# Processing Record 46 of Set 21 | puerto narino
# Processing Record 47 of Set 21 | kamenka
# Processing Record 48 of Set 21 | rio grande
# Processing Record 49 of Set 21 | champerico
# Processing Record 50 of Set 21 | dukat
# Processing Record 1 of Set 22 | amherst
# Processing Record 2 of Set 22 | zhetybay
# City is not found. Skipping...
# Processing Record 3 of Set 22 | daru
# Processing Record 4 of Set 22 | paita
# Processing Record 5 of Set 22 | temaraia
# City is not found. Skipping...
# Processing Record 6 of Set 22 | cowra
# Processing Record 7 of Set 22 | sakakah
# Processing Record 8 of Set 22 | frontignan
# Processing Record 9 of Set 22 | baft
# Processing Record 10 of Set 22 | ambodifototra
# City is not found. Skipping...
# Processing Record 11 of Set 22 | durango
# Processing Record 12 of Set 22 | auki
# Processing Record 13 of Set 22 | saint-alexandre
# Processing Record 14 of Set 22 | terme
# Processing Record 15 of Set 22 | inderborskiy
# City is not found. Skipping...
# Processing Record 16 of Set 22 | taoudenni
# Processing Record 17 of Set 22 | manicore
# Processing Record 18 of Set 22 | gladstone
# Processing Record 19 of Set 22 | kutum
# Processing Record 20 of Set 22 | dire
# Processing Record 21 of Set 22 | bargal
# City is not found. Skipping...
# Processing Record 22 of Set 22 | alamogordo
# Processing Record 23 of Set 22 | yithion
# City is not found. Skipping...
# Processing Record 24 of Set 22 | ayr
# Processing Record 25 of Set 22 | kysyl-syr
# Processing Record 26 of Set 22 | belebey
# ...
# Processing Record 36 of Set 35 | athabasca
# Processing Record 37 of Set 35 | whakatane
# Processing Record 38 of Set 35 | pierre
# Processing Record 39 of Set 35 | safwah
# City is not found. Skipping...
# Processing Record 40 of Set 35 | takoradi
# Processing Record 41 of Set 35 | chilliwack
# Processing Record 42 of Set 35 | westpunt
# City is not found. Skipping...
# Processing Record 43 of Set 35 | mandiana
# Processing Record 44 of Set 35 | chifeng
# Processing Record 45 of Set 35 | abbeville
# Processing Record 46 of Set 35 | ndago
# Processing Record 47 of Set 35 | mergui
# City is not found. Skipping...
# Processing Record 48 of Set 35 | mzimba
# Processing Record 49 of Set 35 | napier
# Processing Record 50 of Set 35 | amga
# Processing Record 1 of Set 36 | todos santos
# Processing Record 2 of Set 36 | drovyanaya
# Processing Record 3 of Set 36 | dwarka
# Processing Record 4 of Set 36 | nemuro
# Processing Record 5 of Set 36 | nilakkottai
# Processing Record 6 of Set 36 | makasar
# Processing Record 7 of Set 36 | sovetskaya
# Processing Record 8 of Set 36 | campos belos
# Processing Record 9 of Set 36 | jiazi
# Processing Record 10 of Set 36 | ostersund
# Processing Record 11 of Set 36 | ust-dzheguta
# Processing Record 12 of Set 36 | lianran
# Processing Record 13 of Set 36 | peikang
# City is not found. Skipping...
# Processing Record 14 of Set 36 | karamea
# City is not found. Skipping...
# Processing Record 15 of Set 36 | roebourne
# Processing Record 16 of Set 36 | mildura
# Processing Record 17 of Set 36 | esna
# Processing Record 18 of Set 36 | utete
# Processing Record 19 of Set 36 | bukachacha
# Processing Record 20 of Set 36 | vega de alatorre
# Processing Record 21 of Set 36 | cranbrook
# Processing Record 22 of Set 36 | wulanhaote
# City is not found. Skipping...
# Processing Record 23 of Set 36 | pembroke
# Processing Record 24 of Set 36 | dicabisagan
# Processing Record 25 of Set 36 | cachoeira
# Processing Record 26 of Set 36 | am timan
# Processing Record 27 of Set 36 | batesville
# Processing Record 28 of Set 36 | umm lajj
# Processing Record 29 of Set 36 | canutama
# Processing Record 30 of Set 36 | yuancheng
# Processing Record 31 of Set 36 | guiratinga
# Processing Record 32 of Set 36 | ucluelet
# Processing Record 33 of Set 36 | pinsk
# Processing Record 34 of Set 36 | atlatlahucan
# Processing Record 35 of Set 36 | svetlogorsk
# Processing Record 36 of Set 36 | kananga
# Processing Record 37 of Set 36 | tolaga bay
# Processing Record 38 of Set 36 | selma
# Processing Record 39 of Set 36 | luorong
# Processing Record 40 of Set 36 | tete
# Processing Record 41 of Set 36 | onega
# Processing Record 42 of Set 36 | chabahar
# Processing Record 43 of Set 36 | jiwani
# Processing Record 44 of Set 36 | tsentralnyy
# City is not found. Skipping...
# Processing Record 45 of Set 36 | san carlos del zulia
# Processing Record 46 of Set 36 | leeuwarden
# Processing Record 47 of Set 36 | floriano
# Processing Record 48 of Set 36 | muyezerskiy
# Processing Record 49 of Set 36 | a
# City is not found. Skipping...
# Processing Record 50 of Set 36 | nur
# Processing Record 1 of Set 37 | matinha
# Processing Record 2 of Set 37 | uvat
# Processing Record 3 of Set 37 | ambulu
# Processing Record 4 of Set 37 | kano
# Processing Record 5 of Set 37 | latung
# Processing Record 6 of Set 37 | bairiki
# Processing Record 7 of Set 37 | baza
# Processing Record 8 of Set 37 | acopiara
# Processing Record 9 of Set 37 | itaituba
# Processing Record 10 of Set 37 | hailar
# Processing Record 11 of Set 37 | brigantine
# Processing Record 12 of Set 37 | kibala
# Processing Record 13 of Set 37 | general pico
# Processing Record 14 of Set 37 | araouane
# Processing Record 15 of Set 37 | pokrovsk
# Processing Record 16 of Set 37 | bealanana
# Processing Record 17 of Set 37 | labytnangi
# Processing Record 18 of Set 37 | helena
# Processing Record 19 of Set 37 | igunga
# Processing Record 20 of Set 37 | xiaoyi
# Processing Record 21 of Set 37 | colquiri
# Processing Record 22 of Set 37 | altamira
# Processing Record 23 of Set 37 | yermish
# Processing Record 24 of Set 37 | hendrina
# Processing Record 25 of Set 37 | skrunda
# Processing Record 26 of Set 37 | mabaruma
# Processing Record 27 of Set 37 | tefe
# Processing Record 28 of Set 37 | pimentel
# Processing Record 29 of Set 37 | florence
# Processing Record 30 of Set 37 | kpandu
# Processing Record 31 of Set 37 | ouesso
# Processing Record 32 of Set 37 | santa vitoria do palmar
# Processing Record 33 of Set 37 | perth
# Processing Record 34 of Set 37 | troitskoye
# Processing Record 35 of Set 37 | manono
# Processing Record 36 of Set 37 | talaya
# Processing Record 37 of Set 37 | asfi
# Processing Record 38 of Set 37 | pangai
# Processing Record 39 of Set 37 | batangafo
# Processing Record 40 of Set 37 | sumbawanga
# Processing Record 41 of Set 37 | mulchen
# Processing Record 42 of Set 37 | jiangmen
# Processing Record 43 of Set 37 | nanchang
# Processing Record 44 of Set 37 | xacmaz
# Processing Record 45 of Set 37 | ondjiva
# Processing Record 46 of Set 37 | caconda
# Processing Record 47 of Set 37 | nikolsk
# Processing Record 48 of Set 37 | sompeta
# Processing Record 49 of Set 37 | tostamaa
# City is not found. Skipping...
# Processing Record 50 of Set 37 | berlin
# Processing Record 1 of Set 38 | westerland
# Processing Record 2 of Set 38 | shubarshi
# Processing Record 3 of Set 38 | camopi
# Processing Record 4 of Set 38 | ban nahin
# Processing Record 5 of Set 38 | anito
# Processing Record 6 of Set 38 | celle
# Processing Record 7 of Set 38 | doncaster
# Processing Record 8 of Set 38 | tias
# Processing Record 9 of Set 38 | mitsamiouli
# Processing Record 10 of Set 38 | sosva
# Processing Record 11 of Set 38 | farah
# Processing Record 12 of Set 38 | praia
# Processing Record 13 of Set 38 | hombourg-haut
# Processing Record 14 of Set 38 | rancho palos verdes
# Processing Record 15 of Set 38 | pocone
# Processing Record 16 of Set 38 | kabalo
# Processing Record 17 of Set 38 | verkhnyaya inta
# Processing Record 18 of Set 38 | morgan city
# Processing Record 19 of Set 38 | kijang
# Processing Record 20 of Set 38 | puerto leguizamo
# Processing Record 21 of Set 38 | miraflores
# Processing Record 22 of Set 38 | boyolangu
# Processing Record 23 of Set 38 | qandahar
# City is not found. Skipping...
# Processing Record 24 of Set 38 | tambo
# Processing Record 25 of Set 38 | bafq
# Processing Record 26 of Set 38 | gasa
# Processing Record 27 of Set 38 | balurghat
# Processing Record 28 of Set 38 | yarkovo
# Processing Record 29 of Set 38 | vaimela
# City is not found. Skipping...
# Processing Record 30 of Set 38 | ilhabela
# Processing Record 31 of Set 38 | killam
# Processing Record 32 of Set 38 | chebenki
# Processing Record 33 of Set 38 | haverfordwest
# Processing Record 34 of Set 38 | albury
# Processing Record 35 of Set 38 | mudon
# Processing Record 36 of Set 38 | maridi
# Processing Record 37 of Set 38 | kirensk
# Processing Record 38 of Set 38 | ati
# Processing Record 39 of Set 38 | severomuysk
# Processing Record 40 of Set 38 | nieuw amsterdam
# Processing Record 41 of Set 38 | bang sai
# Processing Record 42 of Set 38 | huntsville
# Processing Record 43 of Set 38 | mamit
# Processing Record 44 of Set 38 | miandoab
# Processing Record 45 of Set 38 | santa maria del oro
# Processing Record 46 of Set 38 | newala
# Processing Record 47 of Set 38 | rey bouba
# Processing Record 48 of Set 38 | maxixe
# Processing Record 49 of Set 38 | kalloni
# Processing Record 50 of Set 38 | kedgwick
# Processing Record 1 of Set 39 | kofele
# Processing Record 2 of Set 39 | winneba
# Processing Record 3 of Set 39 | tharad
# Processing Record 4 of Set 39 | oloron-sainte-marie
# Processing Record 5 of Set 39 | amurzet
# Processing Record 6 of Set 39 | siniscola
# Processing Record 7 of Set 39 | acari
# Processing Record 8 of Set 39 | maroantsetra
# Processing Record 9 of Set 39 | mayong
# Processing Record 10 of Set 39 | santiago
# Processing Record 11 of Set 39 | lethem
# Processing Record 12 of Set 39 | labrea
# Processing Record 13 of Set 39 | piet retief
# Processing Record 14 of Set 39 | barpeta
# Processing Record 15 of Set 39 | slave lake
# Processing Record 16 of Set 39 | edmond
# Processing Record 17 of Set 39 | fukuma
# Processing Record 18 of Set 39 | ferme-neuve
# Processing Record 19 of Set 39 | anloga
# Processing Record 20 of Set 39 | salta
# Processing Record 21 of Set 39 | sesheke
# Processing Record 22 of Set 39 | bela vista
# Processing Record 23 of Set 39 | ucar
# Processing Record 24 of Set 39 | boundiali
# Processing Record 25 of Set 39 | kamskoye ustye
# Processing Record 26 of Set 39 | pastos bons
# Processing Record 27 of Set 39 | bahia blanca
# Processing Record 28 of Set 39 | minas de barroteran
# Processing Record 29 of Set 39 | baraya
# Processing Record 30 of Set 39 | tongzi
# Processing Record 31 of Set 39 | juba
# Processing Record 32 of Set 39 | ust-koksa
# Processing Record 33 of Set 39 | ubata
# Processing Record 34 of Set 39 | kapit
# Processing Record 35 of Set 39 | bellevue
# Processing Record 36 of Set 39 | gerash
# Processing Record 37 of Set 39 | poway
# Processing Record 38 of Set 39 | carnot
# Processing Record 39 of Set 39 | soe
# Processing Record 40 of Set 39 | genhe
# Processing Record 41 of Set 39 | elat
# Processing Record 42 of Set 39 | viadana
# Processing Record 43 of Set 39 | aalen
# Processing Record 44 of Set 39 | codajas
# Processing Record 45 of Set 39 | arapongas
# Processing Record 46 of Set 39 | zary
# Processing Record 47 of Set 39 | loukhi
# Processing Record 48 of Set 39 | prince george
# Processing Record 49 of Set 39 | ramos arizpe
# Processing Record 50 of Set 39 | bichura
# Processing Record 1 of Set 40 | novaya tavolzhanka
# Processing Record 2 of Set 40 | balaipungut
# Processing Record 3 of Set 40 | ajaccio
# Processing Record 4 of Set 40 | hvammstangi
# City is not found. Skipping...
# Processing Record 5 of Set 40 | levikha
# Processing Record 6 of Set 40 | aleksandrovsk-sakhalinskiy
# Processing Record 7 of Set 40 | paka
# Processing Record 8 of Set 40 | meiktila
# Processing Record 9 of Set 40 | marrakesh
# Processing Record 10 of Set 40 | natal
# Processing Record 11 of Set 40 | banjar
# Processing Record 12 of Set 40 | quata
# Processing Record 13 of Set 40 | sumenep
# Processing Record 14 of Set 40 | xichang
# Processing Record 15 of Set 40 | fenoarivo
# Processing Record 16 of Set 40 | requena
# Processing Record 17 of Set 40 | phek
# Processing Record 18 of Set 40 | port pirie
# Processing Record 19 of Set 40 | rio verde de mato grosso
# Processing Record 20 of Set 40 | kerchevskiy
# Processing Record 21 of Set 40 | ziro
# Processing Record 22 of Set 40 | magdagachi
# Processing Record 23 of Set 40 | amalapuram
# Processing Record 24 of Set 40 | san miguel
# Processing Record 25 of Set 40 | seara
# Processing Record 26 of Set 40 | sorvag
# City is not found. Skipping...
# Processing Record 27 of Set 40 | olbia
# Processing Record 28 of Set 40 | turan
# Processing Record 29 of Set 40 | pathein
# Processing Record 30 of Set 40 | tepalcatepec
# Processing Record 31 of Set 40 | shigony
# Processing Record 32 of Set 40 | dzhebariki-khaya
# Processing Record 33 of Set 40 | togur
# Processing Record 34 of Set 40 | kyshtovka
# Processing Record 35 of Set 40 | mogochin
# City is not found. Skipping...
# Processing Record 36 of Set 40 | post falls
# Processing Record 37 of Set 40 | harlingen
# Processing Record 38 of Set 40 | pemba
# Processing Record 39 of Set 40 | khonuu
# City is not found. Skipping...
# Processing Record 40 of Set 40 | puerto madryn
# Processing Record 41 of Set 40 | pajan
# Processing Record 42 of Set 40 | sandwick
# Processing Record 43 of Set 40 | pindushi
# Processing Record 44 of Set 40 | sarkand
# Processing Record 45 of Set 40 | upington
# Processing Record 46 of Set 40 | kallupatti
# Processing Record 47 of Set 40 | yunyang
# Processing Record 48 of Set 40 | nisia floresta
# Processing Record 49 of Set 40 | spearfish
# Processing Record 50 of Set 40 | asekeyevo
# Processing Record 1 of Set 41 | mbanza-ngungu
# Processing Record 2 of Set 41 | la asuncion
# Processing Record 3 of Set 41 | urucara
# Processing Record 4 of Set 41 | gloria do goita
# Processing Record 5 of Set 41 | treinta y tres
# Processing Record 6 of Set 41 | taraz
# Processing Record 7 of Set 41 | datong
# Processing Record 8 of Set 41 | zverinogolovskoye
# Processing Record 9 of Set 41 | sande
# Processing Record 10 of Set 41 | arcelia
# Processing Record 11 of Set 41 | guadalajara
# Processing Record 12 of Set 41 | anahuac
# Processing Record 13 of Set 41 | cacador
# Processing Record 14 of Set 41 | tabou
# Processing Record 15 of Set 41 | tuensang
# Processing Record 16 of Set 41 | tyazhinskiy
# Processing Record 17 of Set 41 | tanda
# Processing Record 18 of Set 41 | noyabrsk
# Processing Record 19 of Set 41 | puerto cortes
# City is not found. Skipping...
# Processing Record 20 of Set 41 | awbari
# Processing Record 21 of Set 41 | agirish
# Processing Record 22 of Set 41 | chupa
# Processing Record 23 of Set 41 | sheridan
# Processing Record 24 of Set 41 | bytow
# Processing Record 25 of Set 41 | yarumal
# Processing Record 26 of Set 41 | jacqueville
# Processing Record 27 of Set 41 | ilanskiy
# Processing Record 28 of Set 41 | cedar city
# Processing Record 29 of Set 41 | bobo dioulasso
# Processing Record 30 of Set 41 | pedernales
# Processing Record 31 of Set 41 | severnyy
# Processing Record 32 of Set 41 | manado
# Processing Record 33 of Set 41 | madawaska
# Processing Record 34 of Set 41 | antanifotsy
# Processing Record 35 of Set 41 | chumikan
# Processing Record 36 of Set 41 | lazurne
# Processing Record 37 of Set 41 | dubenskiy
# City is not found. Skipping...
# Processing Record 38 of Set 41 | krasnoyarskiy
# Processing Record 39 of Set 41 | baghdad
# Processing Record 40 of Set 41 | mossendjo
# Processing Record 41 of Set 41 | sangin
# Processing Record 42 of Set 41 | ust-kuyga
# Processing Record 43 of Set 41 | steinhagen
# Processing Record 44 of Set 41 | adana
# Processing Record 45 of Set 41 | kosh-agach
# Processing Record 46 of Set 41 | tullahoma
# Processing Record 47 of Set 41 | mataya
# Processing Record 48 of Set 41 | chau doc
# Processing Record 49 of Set 41 | bocas del toro
# Processing Record 50 of Set 41 | dovolnoye
# Processing Record 1 of Set 42 | aginskoye
# Processing Record 2 of Set 42 | sinnar
# Processing Record 3 of Set 42 | oranjestad
# Processing Record 4 of Set 42 | akureyri
# Processing Record 5 of Set 42 | beni
# Processing Record 6 of Set 42 | casa nova
# Processing Record 7 of Set 42 | arusha
# Processing Record 8 of Set 42 | kayseri
# Processing Record 9 of Set 42 | bayir
# Processing Record 10 of Set 42 | fengkou
# Processing Record 11 of Set 42 | youkounkoun
# Processing Record 12 of Set 42 | angoche
# Processing Record 13 of Set 42 | daxian
# City is not found. Skipping...
# Processing Record 14 of Set 42 | baruun-urt
# Processing Record 15 of Set 42 | gazli
# Processing Record 16 of Set 42 | pasighat
# Processing Record 17 of Set 42 | hilton head island
# Processing Record 18 of Set 42 | yerofey pavlovich
# Processing Record 19 of Set 42 | luino
# Processing Record 20 of Set 42 | mumford
# Processing Record 21 of Set 42 | lisala
# Processing Record 22 of Set 42 | goundi
# Processing Record 23 of Set 42 | lufilufi
# Processing Record 24 of Set 42 | octeville
# Processing Record 25 of Set 42 | hukuntsi
# Processing Record 26 of Set 42 | shihezi
# Processing Record 27 of Set 42 | taunggyi
# Processing Record 28 of Set 42 | poya
# Processing Record 29 of Set 42 | bindura
# Processing Record 30 of Set 42 | polis
# Processing Record 31 of Set 42 | puerto madero
# Processing Record 32 of Set 42 | koindu
# Processing Record 33 of Set 42 | ozgon
# City is not found. Skipping...
# Processing Record 34 of Set 42 | palitana
# Processing Record 35 of Set 42 | alanya
# Processing Record 36 of Set 42 | shenjiamen
# Processing Record 37 of Set 42 | kanniyakumari
# Processing Record 38 of Set 42 | saveh
# Processing Record 39 of Set 42 | mentakab
# Processing Record 40 of Set 42 | brookhaven
# Processing Record 41 of Set 42 | limbang
# Processing Record 42 of Set 42 | san jose de buan
# Processing Record 43 of Set 42 | lexington
# Processing Record 44 of Set 42 | novyy urengoy
# Processing Record 45 of Set 42 | skelleftea
# Processing Record 46 of Set 42 | alamos
# Processing Record 47 of Set 42 | nouakchott
# Processing Record 48 of Set 42 | eydhafushi
# Processing Record 49 of Set 42 | kelo
# ----------------------------
# Data Retrieval is Complete
# ----------------------------

# %%
city_data
# Out:
# [{'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 57.09,
#   'Humidity': 71,
#   'Cloudiness': 86,
#   'Wind Speed': 4.32,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lazaro Cardenas',
#   'Country': 'MX',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 75.24,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 3.78,
#   'Current Description': 'few clouds'},
#  {'City': 'Oktyabrskoye',
#   'Country': 'RU',
#   'Lat': 43.0645,
#   'Lng': 44.7417,
#   'Max Temp': 37.54,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 29.79,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 28.62,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 11.56,
#   'Current Description': 'snow'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 42.46,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -17.03,
#   'Humidity': 89,
#   'Cloudiness': 31,
#   'Wind Speed': 12.15,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hovd',
#   'Country': 'MN',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 40.42,
#   'Humidity': 34,
#   'Cloudiness': 91,
#   'Wind Speed': 4.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Igarka',
#   'Country': 'RU',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': 15.28,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 15.17,
#   'Current Description': 'light snow'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 37.42,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 19.57,
#   'Current Description': 'few clouds'},
#  {'City': 'San Ignacio',
#   'Country': 'BZ',
#   'Lat': 17.1561,
#   'Lng': -89.0714,
#   'Max Temp': 66.34,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 5.61,
#   'Humidity': 74,
#   'Cloudiness': 6,
#   'Wind Speed': 5.7,
#   'Current Description': 'clear sky'},
#  {'City': 'Aklavik',
#   'Country': 'CA',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -15.77,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 3.38,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 24.75,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 10.02,
#   'Current Description': 'snow'},
#  {'City': 'Turukhansk',
#   'Country': 'RU',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': 17.24,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 14.92,
#   'Current Description': 'light snow'},
#  {'City': 'Mangrol',
#   'Country': 'IN',
#   'Lat': 21.1167,
#   'Lng': 70.1167,
#   'Max Temp': 85.42,
#   'Humidity': 43,
#   'Cloudiness': 4,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Camacha',
#   'Country': 'PT',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 63.54,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 24.96,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Current Description': 'light snow'},
#  {'City': 'Saint Anthony',
#   'Country': 'US',
#   'Lat': 45.0205,
#   'Lng': -93.218,
#   'Max Temp': 51.58,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Uetze',
#   'Country': 'DE',
#   'Lat': 52.4651,
#   'Lng': 10.2047,
#   'Max Temp': 46.06,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 1.01,
#   'Current Description': 'light intensity drizzle'},
#  {'City': 'Santa Lucia',
#   'Country': 'ES',
#   'Lat': 27.9117,
#   'Lng': -15.5407,
#   'Max Temp': 58.32,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Current Description': 'few clouds'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -32.76,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 76.33,
#   'Humidity': 84,
#   'Cloudiness': 91,
#   'Wind Speed': 16.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Elko',
#   'Country': 'US',
#   'Lat': 41.0002,
#   'Lng': -115.5012,
#   'Max Temp': 32.02,
#   'Humidity': 67,
#   'Cloudiness': 3,
#   'Wind Speed': 5.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 76.17,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 5.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -13.45,
#   'Humidity': 90,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 89.67,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 57.11,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 4.88,
#   'Current Description': 'light rain'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 67.84,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 12.19,
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 9.57,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 8.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -17.54,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chicama',
#   'Country': 'PE',
#   'Lat': -7.8447,
#   'Lng': -79.1469,
#   'Max Temp': 67.06,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 69.76,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 3.24,
#   'Current Description': 'few clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 89.55,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 1.99,
#   'Current Description': 'few clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 12.85,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 6.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hvolsvollur',
#   'Country': 'IS',
#   'Lat': 63.7533,
#   'Lng': -20.2243,
#   'Max Temp': 32.81,
#   'Humidity': 74,
#   'Cloudiness': 4,
#   'Wind Speed': 9.86,
#   'Current Description': 'clear sky'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 73.45,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 86.41,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 25.32,
#   'Current Description': 'clear sky'},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 68.95,
#   'Humidity': 72,
#   'Cloudiness': 44,
#   'Wind Speed': 12.03,
#   'Current Description': 'light rain'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 70.12,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 20.71,
#   'Current Description': 'clear sky'},
#  {'City': 'Buraydah',
#   'Country': 'SA',
#   'Lat': 26.326,
#   'Lng': 43.975,
#   'Max Temp': 61.25,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 10.2,
#   'Current Description': 'clear sky'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 59.94,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Current Description': 'light rain'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 66.87,
#   'Humidity': 83,
#   'Cloudiness': 88,
#   'Wind Speed': 17.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 66.27,
#   'Humidity': 60,
#   'Cloudiness': 39,
#   'Wind Speed': 14.45,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 80.89,
#   'Humidity': 75,
#   'Cloudiness': 37,
#   'Wind Speed': 5.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -21.5,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.67,
#   'Humidity': 77,
#   'Cloudiness': 30,
#   'Wind Speed': 12.62,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -14.8,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Current Description': 'light snow'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 59.81,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 68.56,
#   'Humidity': 82,
#   'Cloudiness': 27,
#   'Wind Speed': 6.93,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 64.15,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 8.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 70.9,
#   'Humidity': 66,
#   'Cloudiness': 13,
#   'Wind Speed': 13.2,
#   'Current Description': 'few clouds'},
#  {'City': 'Lagos',
#   'Country': 'NG',
#   'Lat': 6.5833,
#   'Lng': 3.75,
#   'Max Temp': 77.32,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 0.49,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 71.11,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 26.8,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Current Description': 'clear sky'},
#  {'City': 'Stepnogorsk',
#   'Country': 'KZ',
#   'Lat': 52.3544,
#   'Lng': 71.8869,
#   'Max Temp': 21.87,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 13.09,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 82.94,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 8.08,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.93,
#   'Humidity': 77,
#   'Cloudiness': 98,
#   'Wind Speed': 19.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Songjianghe',
#   'Country': 'CN',
#   'Lat': 42.1859,
#   'Lng': 127.479,
#   'Max Temp': 20.23,
#   'Humidity': 54,
#   'Cloudiness': 2,
#   'Wind Speed': 10.13,
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 82.56,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Floresta',
#   'Country': 'BR',
#   'Lat': -8.6011,
#   'Lng': -38.5686,
#   'Max Temp': 79.41,
#   'Humidity': 52,
#   'Cloudiness': 50,
#   'Wind Speed': 8.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Le Port',
#   'Country': 'RE',
#   'Lat': -20.9373,
#   'Lng': 55.2919,
#   'Max Temp': 84.88,
#   'Humidity': 77,
#   'Cloudiness': 16,
#   'Wind Speed': 13.98,
#   'Current Description': 'few clouds'},
#  {'City': 'Palang',
#   'Country': 'BD',
#   'Lat': 23.2167,
#   'Lng': 90.35,
#   'Max Temp': 86.04,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 5.86,
#   'Current Description': 'clear sky'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 82.65,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -2.18,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 65.1,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zalantun',
#   'Country': 'CN',
#   'Lat': 48,
#   'Lng': 122.7167,
#   'Max Temp': 17.49,
#   'Humidity': 57,
#   'Cloudiness': 24,
#   'Wind Speed': 18.39,
#   'Current Description': 'few clouds'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 35.46,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 22.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Samarkand',
#   'Country': 'UZ',
#   'Lat': 39.6542,
#   'Lng': 66.9597,
#   'Max Temp': 58.42,
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 71.04,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 24.53,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 23,
#   'Current Description': 'broken clouds'},
#  {'City': 'Half Moon Bay',
#   'Country': 'US',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 57.38,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kununurra',
#   'Country': 'AU',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 100.38,
#   'Humidity': 37,
#   'Cloudiness': 21,
#   'Wind Speed': 5.75,
#   'Current Description': 'few clouds'},
#  {'City': 'Mazamari',
#   'Country': 'PE',
#   'Lat': -11.3258,
#   'Lng': -74.5308,
#   'Max Temp': 70.39,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.1,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palmer',
#   'Country': 'US',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 28.08,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 3,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Norsup',
#   'Country': 'VU',
#   'Lat': -16.0667,
#   'Lng': 167.3833,
#   'Max Temp': 76.87,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.55,
#   'Current Description': 'light rain'},
#  {'City': 'Aksarka',
#   'Country': 'RU',
#   'Lat': 66.5606,
#   'Lng': 67.7975,
#   'Max Temp': -3.87,
#   'Humidity': 99,
#   'Cloudiness': 95,
#   'Wind Speed': 3.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 57.24,
#   'Humidity': 85,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Karakol',
#   'Country': 'KG',
#   'Lat': 42.4907,
#   'Lng': 78.3936,
#   'Max Temp': 37.58,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 0.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Gat',
#   'Country': 'IL',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 70.39,
#   'Humidity': 30,
#   'Cloudiness': 12,
#   'Wind Speed': 0.98,
#   'Current Description': 'few clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 66.09,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Current Description': 'clear sky'},
#  {'City': 'Nanortalik',
#   'Country': 'GL',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 36.73,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 13.62,
#   'Current Description': 'light rain'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 55.35,
#   'Humidity': 40,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 83.41,
#   'Humidity': 50,
#   'Cloudiness': 100,
#   'Wind Speed': 15.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 70.75,
#   'Humidity': 62,
#   'Cloudiness': 98,
#   'Wind Speed': 2.53,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porto Santo',
#   'Country': 'PT',
#   'Lat': 33.072,
#   'Lng': -16.3415,
#   'Max Temp': 66.31,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 75.52,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Karatau',
#   'Country': 'KZ',
#   'Lat': 43.1667,
#   'Lng': 70.4667,
#   'Max Temp': 53.71,
#   'Humidity': 42,
#   'Cloudiness': 16,
#   'Wind Speed': 1.43,
#   'Current Description': 'few clouds'},
#  {'City': 'Resistencia',
#   'Country': 'AR',
#   'Lat': -27.4606,
#   'Lng': -58.9839,
#   'Max Temp': 70.11,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Current Description': 'light rain'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 62.82,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 6.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 82.27,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Current Description': 'clear sky'},
#  {'City': 'Kyzyl-Suu',
#   'Country': 'KG',
#   'Lat': 42.3414,
#   'Lng': 78.0056,
#   'Max Temp': 38.84,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 3.11,
#   'Current Description': 'clear sky'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 84.06,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 11.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mattru',
#   'Country': 'SL',
#   'Lat': 7.6244,
#   'Lng': -11.8332,
#   'Max Temp': 74.07,
#   'Humidity': 94,
#   'Cloudiness': 24,
#   'Wind Speed': 1.57,
#   'Current Description': 'few clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 85.08,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 13.35,
#   'Current Description': 'clear sky'},
#  {'City': 'Xiaoshi',
#   'Country': 'CN',
#   'Lat': 41.2971,
#   'Lng': 124.1209,
#   'Max Temp': 30.22,
#   'Humidity': 52,
#   'Cloudiness': 9,
#   'Wind Speed': 3.2,
#   'Current Description': 'clear sky'},
#  {'City': 'Hofn',
#   'Country': 'IS',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 36.39,
#   'Humidity': 60,
#   'Cloudiness': 2,
#   'Wind Speed': 35.03,
#   'Current Description': 'clear sky'},
#  {'City': 'Mogadishu',
#   'Country': 'SO',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 85.87,
#   'Humidity': 79,
#   'Cloudiness': 7,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Pundaguitan',
#   'Country': 'PH',
#   'Lat': 6.3711,
#   'Lng': 126.1689,
#   'Max Temp': 81.84,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 14.32,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 64.69,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'light rain'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 68.09,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.23,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gornopravdinsk',
#   'Country': 'RU',
#   'Lat': 60.05,
#   'Lng': 69.9,
#   'Max Temp': 9.84,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 7.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Santiago Del Estero',
#   'Country': 'AR',
#   'Lat': -27.7951,
#   'Lng': -64.2615,
#   'Max Temp': 65.8,
#   'Humidity': 89,
#   'Cloudiness': 3,
#   'Wind Speed': 6.6,
#   'Current Description': 'clear sky'},
#  {'City': 'Palu',
#   'Country': 'ID',
#   'Lat': -0.8917,
#   'Lng': 119.8707,
#   'Max Temp': 81.03,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 2.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Monrovia',
#   'Country': 'LR',
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 77.31,
#   'Humidity': 87,
#   'Cloudiness': 23,
#   'Wind Speed': 5.95,
#   'Current Description': 'light rain'},
#  {'City': 'Bariri',
#   'Country': 'BR',
#   'Lat': -22.0744,
#   'Lng': -48.7403,
#   'Max Temp': 71.94,
#   'Humidity': 72,
#   'Cloudiness': 41,
#   'Wind Speed': 9.51,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -2.69,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.52,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -22.32,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chute-Aux-Outardes',
#   'Country': 'CA',
#   'Lat': 49.1168,
#   'Lng': -68.399,
#   'Max Temp': 28.71,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Current Description': 'few clouds'},
#  {'City': 'Porto Belo',
#   'Country': 'BR',
#   'Lat': -27.1578,
#   'Lng': -48.5531,
#   'Max Temp': 67.98,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 12.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 76.77,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 63.03,
#   'Humidity': 70,
#   'Cloudiness': 91,
#   'Wind Speed': 9.55,
#   'Current Description': 'light rain'},
#  {'City': 'Seminole',
#   'Country': 'US',
#   'Lat': 28.7086,
#   'Lng': -81.2081,
#   'Max Temp': 58.06,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 1.01,
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 81.79,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 10.09,
#   'Current Description': 'few clouds'},
#  {'City': 'Ust-Tsilma',
#   'Country': 'RU',
#   'Lat': 65.441,
#   'Lng': 52.1498,
#   'Max Temp': 5.7,
#   'Humidity': 98,
#   'Cloudiness': 65,
#   'Wind Speed': 3.47,
#   'Current Description': 'broken clouds'},
#  {'City': 'Coruripe',
#   'Country': 'BR',
#   'Lat': -10.1256,
#   'Lng': -36.1756,
#   'Max Temp': 75.92,
#   'Humidity': 87,
#   'Cloudiness': 24,
#   'Wind Speed': 11.18,
#   'Current Description': 'few clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 41.11,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vila Velha',
#   'Country': 'BR',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 69.94,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Cienaga',
#   'Country': 'CO',
#   'Lat': 11.007,
#   'Lng': -74.2476,
#   'Max Temp': 78.94,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Gbadolite',
#   'Country': 'CD',
#   'Lat': 4.2833,
#   'Lng': 21.0167,
#   'Max Temp': 78.33,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 4.54,
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 37.78,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 24.02,
#   'Current Description': 'light rain'},
#  {'City': 'Merauke',
#   'Country': 'ID',
#   'Lat': -8.4667,
#   'Lng': 140.3333,
#   'Max Temp': 85.55,
#   'Humidity': 68,
#   'Cloudiness': 51,
#   'Wind Speed': 11.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Zinder',
#   'Country': 'NE',
#   'Lat': 13.8072,
#   'Lng': 8.9881,
#   'Max Temp': 75.16,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Current Description': 'clear sky'},
#  {'City': 'Mandalgovi',
#   'Country': 'MN',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 34.7,
#   'Humidity': 28,
#   'Cloudiness': 17,
#   'Wind Speed': 9.44,
#   'Current Description': 'few clouds'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 57.92,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.14,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 82.36,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nalut',
#   'Country': 'LY',
#   'Lat': 30.3333,
#   'Lng': 10.85,
#   'Max Temp': 62.58,
#   'Humidity': 53,
#   'Cloudiness': 5,
#   'Wind Speed': 2.33,
#   'Current Description': 'clear sky'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': -6.39,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.96,
#   'Current Description': 'clear sky'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 45.28,
#   'Humidity': 97,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Current Description': 'light intensity drizzle'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -12.84,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Current Description': 'clear sky'},
#  {'City': 'Coquimbo',
#   'Country': 'CL',
#   'Lat': -29.9533,
#   'Lng': -71.3436,
#   'Max Temp': 58.73,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Country': 'PE',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 62.65,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Porto Novo',
#   'Country': 'BJ',
#   'Lat': 6.4965,
#   'Lng': 2.6036,
#   'Max Temp': 82.22,
#   'Humidity': 81,
#   'Cloudiness': 31,
#   'Wind Speed': 0.87,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Batsfjord',
#   'Country': 'NO',
#   'Lat': 70.6345,
#   'Lng': 29.7185,
#   'Max Temp': 23.22,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'snow'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 82.74,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Current Description': 'light rain'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 84.47,
#   'Humidity': 68,
#   'Cloudiness': 22,
#   'Wind Speed': 10.27,
#   'Current Description': 'few clouds'},
#  {'City': 'Winnemucca',
#   'Country': 'US',
#   'Lat': 40.973,
#   'Lng': -117.7357,
#   'Max Temp': 30.11,
#   'Humidity': 59,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Samarai',
#   'Country': 'PG',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 84.79,
#   'Humidity': 74,
#   'Cloudiness': 34,
#   'Wind Speed': 10.11,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Wenling',
#   'Country': 'CN',
#   'Lat': 28.3669,
#   'Lng': 121.36,
#   'Max Temp': 62.91,
#   'Humidity': 52,
#   'Cloudiness': 17,
#   'Wind Speed': 4,
#   'Current Description': 'few clouds'},
#  {'City': 'Flinders',
#   'Country': 'AU',
#   'Lat': -34.5833,
#   'Lng': 150.8552,
#   'Max Temp': 75.2,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Current Description': 'light rain'},
#  {'City': 'Angoram',
#   'Country': 'PG',
#   'Lat': -4.0625,
#   'Lng': 144.0661,
#   'Max Temp': 81.25,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Current Description': 'moderate rain'},
#  {'City': 'Hearst',
#   'Country': 'CA',
#   'Lat': 49.6835,
#   'Lng': -83.6665,
#   'Max Temp': 26.85,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 10.58,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Careiro Da Varzea',
#   'Country': 'BR',
#   'Lat': -3.2003,
#   'Lng': -59.8119,
#   'Max Temp': 77.61,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dauriya',
#   'Country': 'RU',
#   'Lat': 49.9333,
#   'Lng': 116.8667,
#   'Max Temp': 7.99,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 7.05,
#   'Current Description': 'clear sky'},
#  {'City': 'Yar-Sale',
#   'Country': 'RU',
#   'Lat': 66.8333,
#   'Lng': 70.8333,
#   'Max Temp': 8.13,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Adrar',
#   'Country': 'MR',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 71.28,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 9.55,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Flers',
#   'Country': 'FR',
#   'Lat': 48.7372,
#   'Lng': -0.5747,
#   'Max Temp': 34.05,
#   'Humidity': 98,
#   'Cloudiness': 23,
#   'Wind Speed': 4.47,
#   'Current Description': 'few clouds'},
#  {'City': 'Vestmanna',
#   'Country': 'FO',
#   'Lat': 62.1564,
#   'Lng': -7.1664,
#   'Max Temp': 36.52,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Current Description': 'broken clouds'},
#  {'City': 'Saint-Leu',
#   'Country': 'RE',
#   'Lat': -21.15,
#   'Lng': 55.2833,
#   'Max Temp': 83.95,
#   'Humidity': 77,
#   'Cloudiness': 18,
#   'Wind Speed': 5.39,
#   'Current Description': 'few clouds'},
#  {'City': 'Pampa',
#   'Country': 'US',
#   'Lat': 35.5362,
#   'Lng': -100.9599,
#   'Max Temp': 60.57,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 17.27,
#   'Current Description': 'clear sky'},
#  {'City': 'Orlik',
#   'Country': 'RU',
#   'Lat': 52.5178,
#   'Lng': 99.825,
#   'Max Temp': 18.14,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 2.15,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -25.35,
#   'Humidity': 95,
#   'Cloudiness': 23,
#   'Wind Speed': 3.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Odweyne',
#   'Country': 'SO',
#   'Lat': 9.4092,
#   'Lng': 45.064,
#   'Max Temp': 82.6,
#   'Humidity': 18,
#   'Cloudiness': 8,
#   'Wind Speed': 14.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Beidao',
#   'Country': 'CN',
#   'Lat': 34.5686,
#   'Lng': 105.8933,
#   'Max Temp': 52.93,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 1.9,
#   'Current Description': 'clear sky'},
#  {'City': 'Usinsk',
#   'Country': 'RU',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': 16.72,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 18.45,
#   'Current Description': 'light snow'},
#  {'City': 'Acarau',
#   'Country': 'BR',
#   'Lat': -2.8856,
#   'Lng': -40.12,
#   'Max Temp': 80.71,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 12.59,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kirakira',
#   'Country': 'SB',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 80.42,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 9.66,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 56.89,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 14.97,
#   'Current Description': 'moderate rain'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 83.8,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 16.69,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kiruna',
#   'Country': 'SE',
#   'Lat': 67.8557,
#   'Lng': 20.2251,
#   'Max Temp': 18.52,
#   'Humidity': 79,
#   'Cloudiness': 24,
#   'Wind Speed': 9.22,
#   'Current Description': 'few clouds'},
#  {'City': 'Lasa',
#   'Country': 'IT',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 34.68,
#   'Humidity': 52,
#   'Cloudiness': 2,
#   'Wind Speed': 0.81,
#   'Current Description': 'clear sky'},
#  {'City': 'Tigil',
#   'Country': 'RU',
#   'Lat': 57.8,
#   'Lng': 158.6667,
#   'Max Temp': 26.06,
#   'Humidity': 73,
#   'Cloudiness': 63,
#   'Wind Speed': 11.9,
#   'Current Description': 'broken clouds'},
#  {'City': 'Atasu',
#   'Country': 'KZ',
#   'Lat': 48.6814,
#   'Lng': 71.6433,
#   'Max Temp': 35.62,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 15.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 78.91,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 0,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Kruisfontein',
#   'Country': 'ZA',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 59.88,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 5.19,
#   'Current Description': 'light rain'},
#  {'City': 'Kudahuvadhoo',
#   'Country': 'MV',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 82.47,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 16.96,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Riyadh',
#   'Country': 'SA',
#   'Lat': 24.6877,
#   'Lng': 46.7219,
#   'Max Temp': 64.54,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 8.1,
#   'Current Description': 'clear sky'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 31.19,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Current Description': 'clear sky'},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 78.78,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 14,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.83,
#   'Humidity': 96,
#   'Cloudiness': 65,
#   'Wind Speed': 4.52,
#   'Current Description': 'broken clouds'},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 32.94,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 39.86,
#   'Current Description': 'snow'},
#  {'City': 'Tanout',
#   'Country': 'NE',
#   'Lat': 14.9709,
#   'Lng': 8.8879,
#   'Max Temp': 76.39,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 9.06,
#   'Current Description': 'clear sky'},
#  {'City': 'Bonavista',
#   'Country': 'CA',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 45.12,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 25.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Inirida',
#   'Country': 'CO',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 72.48,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Baldone',
#   'Country': 'LV',
#   'Lat': 56.7428,
#   'Lng': 24.3944,
#   'Max Temp': 37.15,
#   'Humidity': 95,
#   'Cloudiness': 84,
#   'Wind Speed': 10.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Jalu',
#   'Country': 'LY',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 69.85,
#   'Humidity': 28,
#   'Cloudiness': 27,
#   'Wind Speed': 2.98,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Praya',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 76.44,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 8.16,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 71.37,
#   'Humidity': 53,
#   'Cloudiness': 10,
#   'Wind Speed': 19.26,
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 67.01,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 11.07,
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Rafael',
#   'Country': 'AR',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 71.58,
#   'Humidity': 57,
#   'Cloudiness': 2,
#   'Wind Speed': 8.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 82.69,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Jiuquan',
#   'Country': 'CN',
#   'Lat': 39.7432,
#   'Lng': 98.5174,
#   'Max Temp': 44.94,
#   'Humidity': 20,
#   'Cloudiness': 7,
#   'Wind Speed': 1.92,
#   'Current Description': 'clear sky'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 59.05,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Current Description': 'moderate rain'},
#  {'City': 'Macamic',
#   'Country': 'CA',
#   'Lat': 48.7502,
#   'Lng': -78.9996,
#   'Max Temp': 16.03,
#   'Humidity': 80,
#   'Cloudiness': 85,
#   'Wind Speed': 12.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Pierre',
#   'Country': 'RE',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 84.56,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Current Description': 'few clouds'},
#  {'City': 'Honningsvag',
#   'Country': 'NO',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 22.75,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Cooma',
#   'Country': 'AU',
#   'Lat': -36.2333,
#   'Lng': 149.1333,
#   'Max Temp': 64.17,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Smithers',
#   'Country': 'CA',
#   'Lat': 54.7804,
#   'Lng': -127.1743,
#   'Max Temp': 23.32,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Current Description': 'broken clouds'},
#  {'City': 'Bulancak',
#   'Country': 'TR',
#   'Lat': 40.9372,
#   'Lng': 38.2291,
#   'Max Temp': 54.28,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 11.56,
#   'Current Description': 'light rain'},
#  {'City': 'Padang',
#   'Country': 'ID',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 87.85,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 4.56,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Banikoara',
#   'Country': 'BJ',
#   'Lat': 11.2985,
#   'Lng': 2.4386,
#   'Max Temp': 76.06,
#   'Humidity': 26,
#   'Cloudiness': 75,
#   'Wind Speed': 3.49,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kavaratti',
#   'Country': 'IN',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 78.58,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barcelos',
#   'Country': 'PT',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 49.28,
#   'Humidity': 88,
#   'Cloudiness': 14,
#   'Wind Speed': 3.83,
#   'Current Description': 'few clouds'},
#  {'City': 'Ternate',
#   'Country': 'ID',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 84.78,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Current Description': 'light rain'},
#  {'City': 'Mao',
#   'Country': 'ES',
#   'Lat': 39.8885,
#   'Lng': 4.2658,
#   'Max Temp': 54.16,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 37.02,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 13.85,
#   'Current Description': 'light snow'},
#  {'City': 'Amapa',
#   'Country': 'BR',
#   'Lat': 1,
#   'Lng': -52,
#   'Max Temp': 70.07,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manzhouli',
#   'Country': 'CN',
#   'Lat': 49.6,
#   'Lng': 117.4333,
#   'Max Temp': 9.34,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 7.23,
#   'Current Description': 'clear sky'},
#  {'City': 'Mehamn',
#   'Country': 'NO',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 23.18,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Current Description': 'light snow'},
#  {'City': 'Hakodate',
#   'Country': 'JP',
#   'Lat': 41.7758,
#   'Lng': 140.7367,
#   'Max Temp': 32.31,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'light shower snow'},
#  {'City': 'Ukiah',
#   'Country': 'US',
#   'Lat': 39.1502,
#   'Lng': -123.2078,
#   'Max Temp': 55.04,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Current Description': 'clear sky'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 82.78,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 72.23,
#   'Humidity': 36,
#   'Cloudiness': 9,
#   'Wind Speed': 8.46,
#   'Current Description': 'clear sky'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 49.35,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 0,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tiksi',
#   'Country': 'RU',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -20.56,
#   'Humidity': 98,
#   'Cloudiness': 39,
#   'Wind Speed': 7.58,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Poum',
#   'Country': 'NC',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 77.95,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mathbaria',
#   'Country': 'BD',
#   'Lat': 22.2876,
#   'Lng': 89.9593,
#   'Max Temp': 86.94,
#   'Humidity': 41,
#   'Cloudiness': 17,
#   'Wind Speed': 5.23,
#   'Current Description': 'few clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 61.2,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 13.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Shimoda',
#   'Country': 'JP',
#   'Lat': 34.6667,
#   'Lng': 138.95,
#   'Max Temp': 55.76,
#   'Humidity': 66,
#   'Cloudiness': 2,
#   'Wind Speed': 32.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Leh',
#   'Country': 'IN',
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 26.02,
#   'Humidity': 44,
#   'Cloudiness': 23,
#   'Wind Speed': 3.09,
#   'Current Description': 'few clouds'},
#  {'City': 'Karabuk',
#   'Country': 'TR',
#   'Lat': 41.2049,
#   'Lng': 32.6277,
#   'Max Temp': 49.59,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bambari',
#   'Country': 'CF',
#   'Lat': 5.768,
#   'Lng': 20.6757,
#   'Max Temp': 80.51,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 3.65,
#   'Current Description': 'clear sky'},
#  {'City': 'Maracaju',
#   'Country': 'BR',
#   'Lat': -21.6144,
#   'Lng': -55.1683,
#   'Max Temp': 75.74,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Country': 'RU',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 37.99,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 15.66,
#   'Current Description': 'light rain'},
#  {'City': 'Sholapur',
#   'Country': 'IN',
#   'Lat': 17.6833,
#   'Lng': 75.9167,
#   'Max Temp': 86.72,
#   'Humidity': 48,
#   'Cloudiness': 8,
#   'Wind Speed': 10.74,
#   'Current Description': 'clear sky'},
#  {'City': 'Dingle',
#   'Country': 'PH',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 80.8,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 13.27,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belaya Gora',
#   'Country': 'RU',
#   'Lat': 68.5333,
#   'Lng': 146.4167,
#   'Max Temp': -21.41,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 0.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 53.83,
#   'Humidity': 82,
#   'Cloudiness': 63,
#   'Wind Speed': 14.58,
#   'Current Description': 'broken clouds'},
#  {'City': 'Along',
#   'Country': 'IN',
#   'Lat': 28.1667,
#   'Lng': 94.7667,
#   'Max Temp': 78.26,
#   'Humidity': 40,
#   'Cloudiness': 8,
#   'Wind Speed': 1.79,
#   'Current Description': 'clear sky'},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 33.46,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 2.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Diamantino',
#   'Country': 'BR',
#   'Lat': -14.4086,
#   'Lng': -56.4461,
#   'Max Temp': 72.52,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.04,
#   'Current Description': 'light rain'},
#  {'City': 'Flagstaff',
#   'Country': 'US',
#   'Lat': 35.1981,
#   'Lng': -111.6513,
#   'Max Temp': 43.12,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 1.99,
#   'Current Description': 'broken clouds'},
#  {'City': 'Gravdal',
#   'Country': 'NO',
#   'Lat': 68.1214,
#   'Lng': 13.5031,
#   'Max Temp': 30.09,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Goderich',
#   'Country': 'CA',
#   'Lat': 43.7501,
#   'Lng': -81.7165,
#   'Max Temp': 32.32,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 8.05,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ulladulla',
#   'Country': 'AU',
#   'Lat': -35.35,
#   'Lng': 150.4667,
#   'Max Temp': 72.5,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 7.81,
#   'Current Description': 'moderate rain'},
#  {'City': 'Ulcinj',
#   'Country': 'ME',
#   'Lat': 41.9294,
#   'Lng': 19.2244,
#   'Max Temp': 52.02,
#   'Humidity': 71,
#   'Cloudiness': 10,
#   'Wind Speed': 13.42,
#   'Current Description': 'clear sky'},
#  {'City': 'Fray Bentos',
#   'Country': 'UY',
#   'Lat': -33.1325,
#   'Lng': -58.2956,
#   'Max Temp': 55.53,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 8.34,
#   'Current Description': 'clear sky'},
#  {'City': 'State College',
#   'Country': 'US',
#   'Lat': 40.7934,
#   'Lng': -77.86,
#   'Max Temp': 28.8,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Aracoiaba',
#   'Country': 'BR',
#   'Lat': -4.3711,
#   'Lng': -38.8142,
#   'Max Temp': 75.6,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 3.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Civitavecchia',
#   'Country': 'IT',
#   'Lat': 42.0933,
#   'Lng': 11.7967,
#   'Max Temp': 52.61,
#   'Humidity': 84,
#   'Cloudiness': 12,
#   'Wind Speed': 5.5,
#   'Current Description': 'few clouds'},
#  {'City': 'Dimitrovgrad',
#   'Country': 'RU',
#   'Lat': 54.2139,
#   'Lng': 49.6184,
#   'Max Temp': 14.05,
#   'Humidity': 90,
#   'Cloudiness': 20,
#   'Wind Speed': 5.93,
#   'Current Description': 'few clouds'},
#  {'City': 'West Wendover',
#   'Country': 'US',
#   'Lat': 40.7391,
#   'Lng': -114.0733,
#   'Max Temp': 34.81,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Current Description': 'clear sky'},
#  {'City': 'Inta',
#   'Country': 'RU',
#   'Lat': 66.0317,
#   'Lng': 60.1659,
#   'Max Temp': 16.05,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 17.67,
#   'Current Description': 'light snow'},
#  {'City': 'Riachao',
#   'Country': 'BR',
#   'Lat': -7.3619,
#   'Lng': -46.6172,
#   'Max Temp': 71.64,
#   'Humidity': 91,
#   'Cloudiness': 38,
#   'Wind Speed': 3.27,
#   'Current Description': 'light rain'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': -1.34,
#   'Humidity': 90,
#   'Cloudiness': 5,
#   'Wind Speed': 8.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Buala',
#   'Country': 'SB',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 82.87,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Trelew',
#   'Country': 'AR',
#   'Lat': -43.249,
#   'Lng': -65.3051,
#   'Max Temp': 66.42,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 15.68,
#   'Current Description': 'clear sky'},
#  {'City': 'Valdivia',
#   'Country': 'CL',
#   'Lat': -39.8142,
#   'Lng': -73.2459,
#   'Max Temp': 55.49,
#   'Humidity': 99,
#   'Cloudiness': 19,
#   'Wind Speed': 2.1,
#   'Current Description': 'few clouds'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 81.09,
#   'Humidity': 86,
#   'Cloudiness': 27,
#   'Wind Speed': 1.01,
#   'Current Description': 'scattered clouds'},
#  {'City': 'San Antonio',
# ...
#   'Max Temp': 25.57,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 9.89,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Wawa',
#   'Country': 'NG',
#   'Lat': 9.9022,
#   'Lng': 4.4192,
#   'Max Temp': 76.95,
#   'Humidity': 47,
#   'Cloudiness': 21,
#   'Wind Speed': 4.65,
#   'Current Description': 'few clouds'},
#  {'City': 'Vangaindrano',
#   'Country': 'MG',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 91.02,
#   'Humidity': 50,
#   'Cloudiness': 23,
#   'Wind Speed': 5.01,
#   'Current Description': 'few clouds'},
#  {'City': 'Mikkeli',
#   'Country': 'FI',
#   'Lat': 61.6886,
#   'Lng': 27.2723,
#   'Max Temp': 35.71,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kokopo',
#   'Country': 'PG',
#   'Lat': -4.352,
#   'Lng': 152.2633,
#   'Max Temp': 82.76,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 0.65,
#   'Current Description': 'light rain'},
#  {'City': 'Brae',
#   'Country': 'GB',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 46.31,
#   'Humidity': 67,
#   'Cloudiness': 63,
#   'Wind Speed': 22.21,
#   'Current Description': 'broken clouds'},
#  {'City': 'Totma',
#   'Country': 'RU',
#   'Lat': 59.9747,
#   'Lng': 42.7642,
#   'Max Temp': 19.72,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.4,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nichinan',
#   'Country': 'JP',
#   'Lat': 31.6,
#   'Lng': 131.3667,
#   'Max Temp': 53.76,
#   'Humidity': 56,
#   'Cloudiness': 22,
#   'Wind Speed': 9.26,
#   'Current Description': 'few clouds'},
#  {'City': 'Castelo Do Piaui',
#   'Country': 'BR',
#   'Lat': -5.3222,
#   'Lng': -41.5525,
#   'Max Temp': 74.82,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 0.54,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Olga',
#   'Country': 'RU',
#   'Lat': 43.7444,
#   'Lng': 135.2892,
#   'Max Temp': 26.19,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 12.33,
#   'Current Description': 'broken clouds'},
#  {'City': 'Guildford',
#   'Country': 'GB',
#   'Lat': 51.2354,
#   'Lng': -0.5743,
#   'Max Temp': 44.13,
#   'Humidity': 88,
#   'Cloudiness': 6,
#   'Wind Speed': 2.62,
#   'Current Description': 'clear sky'},
#  {'City': 'San Rafael Del Sur',
#   'Country': 'NI',
#   'Lat': 11.8485,
#   'Lng': -86.4384,
#   'Max Temp': 75.4,
#   'Humidity': 74,
#   'Cloudiness': 65,
#   'Wind Speed': 12.33,
#   'Current Description': 'broken clouds'},
#  {'City': 'Panguipulli',
#   'Country': 'CL',
#   'Lat': -39.6333,
#   'Lng': -72.3333,
#   'Max Temp': 56.91,
#   'Humidity': 99,
#   'Cloudiness': 12,
#   'Wind Speed': 1.52,
#   'Current Description': 'few clouds'},
#  {'City': 'Noumea',
#   'Country': 'NC',
#   'Lat': -22.2763,
#   'Lng': 166.4572,
#   'Max Temp': 80.01,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 9.04,
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Jatiroto',
#   'Country': 'ID',
#   'Lat': -7.8833,
#   'Lng': 111.1167,
#   'Max Temp': 81.41,
#   'Humidity': 78,
#   'Cloudiness': 99,
#   'Wind Speed': 2.35,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chimoio',
#   'Country': 'MZ',
#   'Lat': -19.1164,
#   'Lng': 33.4833,
#   'Max Temp': 79.57,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kodinar',
#   'Country': 'IN',
#   'Lat': 20.7903,
#   'Lng': 70.7031,
#   'Max Temp': 87.51,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind Speed': 2.17,
#   'Current Description': 'clear sky'},
#  {'City': 'Manacapuru',
#   'Country': 'BR',
#   'Lat': -3.2997,
#   'Lng': -60.6206,
#   'Max Temp': 75.78,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.87,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Coahuayana',
#   'Country': 'MX',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 72.79,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.2,
#   'Current Description': 'few clouds'},
#  {'City': 'Mana',
#   'Country': 'GF',
#   'Lat': 5.6592,
#   'Lng': -53.7767,
#   'Max Temp': 77.95,
#   'Humidity': 88,
#   'Cloudiness': 88,
#   'Wind Speed': 7.83,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Verdun',
#   'Country': 'FR',
#   'Lat': 49.25,
#   'Lng': 5.3333,
#   'Max Temp': 38.1,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 8.86,
#   'Current Description': 'clear sky'},
#  {'City': 'Eston',
#   'Country': 'CA',
#   'Lat': 51.1501,
#   'Lng': -108.7514,
#   'Max Temp': 10.92,
#   'Humidity': 91,
#   'Cloudiness': 25,
#   'Wind Speed': 12.15,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kokstad',
#   'Country': 'ZA',
#   'Lat': -30.5472,
#   'Lng': 29.4241,
#   'Max Temp': 48.25,
#   'Humidity': 77,
#   'Cloudiness': 93,
#   'Wind Speed': 7.18,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Locri',
#   'Country': 'IT',
#   'Lat': 38.2414,
#   'Lng': 16.2623,
#   'Max Temp': 61.16,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 2.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Macquarie',
#   'Country': 'AU',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 72.9,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 13.62,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mananjary',
#   'Country': 'MG',
#   'Lat': -21.2167,
#   'Lng': 48.3333,
#   'Max Temp': 87.98,
#   'Humidity': 56,
#   'Cloudiness': 11,
#   'Wind Speed': 13.11,
#   'Current Description': 'few clouds'},
#  {'City': 'Tommot',
#   'Country': 'RU',
#   'Lat': 58.9564,
#   'Lng': 126.2925,
#   'Max Temp': -4.94,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Soyo',
#   'Country': 'AO',
#   'Lat': -6.1349,
#   'Lng': 12.3689,
#   'Max Temp': 79.79,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sangar',
#   'Country': 'RU',
#   'Lat': 63.9242,
#   'Lng': 127.4739,
#   'Max Temp': -27.29,
#   'Humidity': 99,
#   'Cloudiness': 12,
#   'Wind Speed': 2.86,
#   'Current Description': 'few clouds'},
#  {'City': 'Nioro',
#   'Country': 'GM',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 73.06,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 40.69,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 12.66,
#   'Current Description': 'light rain'},
#  {'City': 'Ludvika',
#   'Country': 'SE',
#   'Lat': 60.1496,
#   'Lng': 15.1878,
#   'Max Temp': 37.2,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.06,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Heinola',
#   'Country': 'FI',
#   'Lat': 61.2056,
#   'Lng': 26.0381,
#   'Max Temp': 37.49,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 13.96,
#   'Current Description': 'light snow'},
#  {'City': 'Puerto Narino',
#   'Country': 'CO',
#   'Lat': -3.7703,
#   'Lng': -70.3831,
#   'Max Temp': 72.09,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.76,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 20.75,
#   'Humidity': 66,
#   'Cloudiness': 8,
#   'Wind Speed': 4.21,
#   'Current Description': 'clear sky'},
#  {'City': 'Rio Grande',
#   'Country': 'BR',
#   'Lat': -32.035,
#   'Lng': -52.0986,
#   'Max Temp': 59.77,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 7.25,
#   'Current Description': 'clear sky'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 79.03,
#   'Humidity': 84,
#   'Cloudiness': 9,
#   'Wind Speed': 5.39,
#   'Current Description': 'clear sky'},
#  {'City': 'Dukat',
#   'Country': 'RU',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': -7.92,
#   'Humidity': 100,
#   'Cloudiness': 86,
#   'Wind Speed': 3.02,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Amherst',
#   'Country': 'US',
#   'Lat': 41.3978,
#   'Lng': -82.2224,
#   'Max Temp': 32.41,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 1.99,
#   'Current Description': 'clear sky'},
#  {'City': 'Daru',
#   'Country': 'PG',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 84.97,
#   'Humidity': 73,
#   'Cloudiness': 10,
#   'Wind Speed': 9.51,
#   'Current Description': 'clear sky'},
#  {'City': 'Paita',
#   'Country': 'PE',
#   'Lat': -5.0892,
#   'Lng': -81.1144,
#   'Max Temp': 64.96,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 9.33,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cowra',
#   'Country': 'AU',
#   'Lat': -33.8333,
#   'Lng': 148.6833,
#   'Max Temp': 74.26,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Current Description': 'light rain'},
#  {'City': 'Sakakah',
#   'Country': 'SA',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 63.97,
#   'Humidity': 45,
#   'Cloudiness': 30,
#   'Wind Speed': 7.38,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Frontignan',
#   'Country': 'FR',
#   'Lat': 43.4485,
#   'Lng': 3.754,
#   'Max Temp': 48.34,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 17.27,
#   'Current Description': 'moderate rain'},
#  {'City': 'Baft',
#   'Country': 'IR',
#   'Lat': 29.234,
#   'Lng': 56.6057,
#   'Max Temp': 55.08,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 8.55,
#   'Current Description': 'clear sky'},
#  {'City': 'Durango',
#   'Country': 'MX',
#   'Lat': 24.8333,
#   'Lng': -104.8333,
#   'Max Temp': 53.29,
#   'Humidity': 64,
#   'Cloudiness': 48,
#   'Wind Speed': 6.35,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Auki',
#   'Country': 'SB',
#   'Lat': -8.7676,
#   'Lng': 160.7034,
#   'Max Temp': 81.34,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.47,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint-Alexandre',
#   'Country': 'FR',
#   'Lat': 44.2278,
#   'Lng': 4.6214,
#   'Max Temp': 45.59,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.84,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Terme',
#   'Country': 'TR',
#   'Lat': 41.2092,
#   'Lng': 36.9739,
#   'Max Temp': 54.97,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.7,
#   'Current Description': 'light rain'},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 74.59,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 5.41,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Manicore',
#   'Country': 'BR',
#   'Lat': -5.8092,
#   'Lng': -61.3003,
#   'Max Temp': 73.31,
#   'Humidity': 88,
#   'Cloudiness': 44,
#   'Wind Speed': 0.78,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gladstone',
#   'Country': 'AU',
#   'Lat': -23.85,
#   'Lng': 151.25,
#   'Max Temp': 80.53,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 11.5,
#   'Current Description': 'light rain'},
#  {'City': 'Kutum',
#   'Country': 'SD',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 66.96,
#   'Humidity': 17,
#   'Cloudiness': 1,
#   'Wind Speed': 9.84,
#   'Current Description': 'clear sky'},
#  {'City': 'Dire',
#   'Country': 'ML',
#   'Lat': 12.2833,
#   'Lng': -10.9667,
#   'Max Temp': 69.06,
#   'Humidity': 36,
#   'Cloudiness': 8,
#   'Wind Speed': 1.5,
#   'Current Description': 'clear sky'},
#  {'City': 'Alamogordo',
#   'Country': 'US',
#   'Lat': 32.8995,
#   'Lng': -105.9603,
#   'Max Temp': 62.56,
#   'Humidity': 43,
#   'Cloudiness': 40,
#   'Wind Speed': 4,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ayr',
#   'Country': 'GB',
#   'Lat': 55.4627,
#   'Lng': -4.6339,
#   'Max Temp': 48.18,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Current Description': 'broken clouds'},
#  {'City': 'Kysyl-Syr',
#   'Country': 'RU',
#   'Lat': 63.8986,
#   'Lng': 122.7617,
#   'Max Temp': -22.16,
#   'Humidity': 97,
#   'Cloudiness': 8,
#   'Wind Speed': 4.18,
#   'Current Description': 'clear sky'},
#  {'City': 'Belebey',
#   'Country': 'RU',
#   'Lat': 54.1167,
#   'Lng': 54.1167,
#   'Max Temp': 5.25,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Havoysund',
#   'Country': 'NO',
#   'Lat': 70.9963,
#   'Lng': 24.6622,
#   'Max Temp': 23.23,
#   'Humidity': 74,
#   'Cloudiness': 62,
#   'Wind Speed': 8.05,
#   'Current Description': 'light snow'},
#  {'City': 'Verkhoturye',
#   'Country': 'RU',
#   'Lat': 58.8627,
#   'Lng': 60.8054,
#   'Max Temp': 17.13,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.19,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Springbok',
#   'Country': 'ZA',
#   'Lat': -29.6643,
#   'Lng': 17.8865,
#   'Max Temp': 69.73,
#   'Humidity': 34,
#   'Cloudiness': 95,
#   'Wind Speed': 4.34,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Russell',
#   'Country': 'US',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 40.23,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 0,
#   'Current Description': 'clear sky'},
#  {'City': 'Simao',
#   'Country': 'CN',
#   'Lat': 22.7886,
#   'Lng': 100.9748,
#   'Max Temp': 59.13,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.39,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vieques',
#   'Country': 'PR',
#   'Lat': 18.425,
#   'Lng': -65.8329,
#   'Max Temp': 77.02,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Current Description': 'few clouds'},
#  {'City': 'Batemans Bay',
#   'Country': 'AU',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 75.99,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.61,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Haukipudas',
#   'Country': 'FI',
#   'Lat': 65.1765,
#   'Lng': 25.3523,
#   'Max Temp': 26.65,
#   'Humidity': 93,
#   'Cloudiness': 11,
#   'Wind Speed': 14.25,
#   'Current Description': 'few clouds'},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 80.15,
#   'Humidity': 39,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Current Description': 'broken clouds'},
#  {'City': 'Portales',
#   'Country': 'US',
#   'Lat': 34.1862,
#   'Lng': -103.3344,
#   'Max Temp': 53.02,
#   'Humidity': 50,
#   'Cloudiness': 93,
#   'Wind Speed': 1.99,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Xiamen',
#   'Country': 'CN',
#   'Lat': 24.4798,
#   'Lng': 118.0819,
#   'Max Temp': 69.85,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Current Description': 'clear sky'},
#  {'City': 'Geilo',
#   'Country': 'NO',
#   'Lat': 60.5333,
#   'Lng': 8.2076,
#   'Max Temp': 41.4,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aden',
#   'Country': 'YE',
#   'Lat': 12.7794,
#   'Lng': 45.0367,
#   'Max Temp': 81.09,
#   'Humidity': 64,
#   'Cloudiness': 27,
#   'Wind Speed': 5.48,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Shache',
#   'Country': 'CN',
#   'Lat': 38.4167,
#   'Lng': 77.2406,
#   'Max Temp': 40.91,
#   'Humidity': 26,
#   'Cloudiness': 96,
#   'Wind Speed': 2.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Camana',
#   'Country': 'PE',
#   'Lat': -16.6228,
#   'Lng': -72.7111,
#   'Max Temp': 66.07,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13,
#   'Current Description': 'moderate rain'},
#  {'City': 'Vanderhoof',
#   'Country': 'CA',
#   'Lat': 54.0166,
#   'Lng': -124.0198,
#   'Max Temp': 26.33,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 2.28,
#   'Current Description': 'overcast clouds'},
#  {'City': 'Strathmore',
#   'Country': 'CA',
#   'Lat': 51.0501,
#   'Lng': -113.3852,
#   'Max Temp': 22.01,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Current Description': 'light snow'},
#  {'City': 'Kathmandu',
#   'Country': 'NP',
#   'Lat': 27.7167,
#   'Lng': 85.3167,
#   'Max Temp': 68.22,
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Current Description': 'few clouds'},
#  {'City': 'Franca',
#   'Country': 'BR',
#   'Lat': -20.5386,
#   'Lng': -47.4008,
#   'Max Temp': 65.64,
#   'Humidity': 58,
#   'Cloudiness': 35,
#   'Wind Speed': 4.21,
#   'Current Description': 'scattered clouds'},
#  {'City': 'Abinsk',
#   'Country': 'RU',
#   'Lat': 44.8726,
#   'Lng': 38.1611,
#   'Max Temp': 39.36,
#   'Humidity': 64,
#   'Cloudiness': 12,
#   'Wind Speed': 10.56,
#   'Current Description': 'few clouds'},
#  {'City': 'Les Escoumins',
#   'Country': 'CA',
#   'Lat': 48.1111,
#   'Lng': -69.0236,
#   'Max Temp': 25.95,
#   'Humidity': 70,
#   'Cloudiness': 78,
#   'Wind Speed': 12.5,
#   'Current Description': 'broken clouds'},
#  {'City': 'La Rioja',
#   'Country': 'ES',
#   'Lat': 42.25,
#   'Lng': -2.5,
#   'Max Temp': 36.48,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.53,
#   'Current Description': 'overcast clouds'},
#  ...]

# %%
# Retrieve the following information from the API call:

n=0
city_list=[]
country_list=[]
lat_list=[]
long_list=[]
max_temp_list=[]
humidity_list=[]
cloudiness_list=[]
wind_speed_list=[]
current_condition_list=[]

for i in city_data:
    
    city = city_data[n]['City']
    city_list.append(city)
    
    country=city_data[n]['Country']
    country_list.append(country)

    # Latitude and longitude
    lat = city_data[n]['Lat']
    lat_list.append(lat)
    
    long = city_data[n]['Lng']
    long_list.append(long)

    # Maximum temperature
    max_temp = city_data[n]['Max Temp']
    max_temp_list.append(max_temp)

    # Percent humidity
    humidity = city_data[n]['Humidity']
    humidity_list.append(humidity)

    # Percent cloudiness
    cloudiness = city_data[n]['Cloudiness']
    cloudiness_list.append(cloudiness)

    # Wind speed
    wind_speed = city_data[n]['Wind Speed']
    wind_speed_list.append(wind_speed)

    # Weather description (for example, clouds, fog, light rain, clear sky)
    current_condition = city_data[n]['Current Description']
    current_condition_list.append(current_condition)
    
    #increase n iterator
    n += 1

# %%
# Add the data to a new DataFrame.
city_wx_df = pd.DataFrame()

city_wx_df['City'] = city_list
city_wx_df['Country'] = country_list
city_wx_df['Lat'] = lat_list
city_wx_df['Lng'] = long_list
city_wx_df['Max Temp'] = max_temp_list
city_wx_df['Humidity'] = humidity_list
city_wx_df['Cloudiness'] = cloudiness_list
city_wx_df['Wind Speed'] = wind_speed_list
city_wx_df['Current Description'] = current_condition_list

city_wx_df
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Kaitangata      NZ -46.2817  169.8464     57.09        71
# 1     Lazaro Cardenas      MX  17.9583 -102.2000     75.24        90
# 2        Oktyabrskoye      RU  43.0645   44.7417     37.54        93
# 3           Jamestown      US  42.0970  -79.2353     29.79        82
# 4              Narsaq      GL  60.9167  -46.0500     28.62        95
# ...               ...     ...      ...       ...       ...       ...
# 1921       Skelleftea      SE  64.7507   20.9528     26.96        66
# 1922           Alamos      MX  27.0167 -108.9333     61.45        91
# 1923       Nouakchott      MR  18.0858  -15.9785     73.33        42
# 1924       Eydhafushi      MV   5.1033   73.0708     81.70        70
# 1925             Kelo      TD   9.3086   15.8066     87.30        19
#
#       Cloudiness  Wind Speed Current Description
# 0             86        4.32     overcast clouds
# 1             20        3.78          few clouds
# 2             90        4.47     overcast clouds
# 3              1        1.99           clear sky
# 4            100       11.56                snow
# ...          ...         ...                 ...
# 1921           0        9.22           clear sky
# 1922          11        2.39          few clouds
# 1923         100       11.34     overcast clouds
# 1924         100       16.55     overcast clouds
# 1925           5        4.12           clear sky
#
# [1926 rows x 9 columns]

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
city_wx_df.to_csv('WeatherPy_Database.csv')
